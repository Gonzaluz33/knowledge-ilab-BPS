# %% [markdown]
# ## Project Overview
#
# InstructLab uses a novel synthetic data-based alignment tuning method for Large Language Models (LLMs.) The "**lab**" in Instruct**Lab** stands for **L**arge-Scale **A**lignment for Chat**B**ots.
#
# It is an outgrowth of the paper [*LAB: Large-Scale Alignment for ChatBots*](https://arxiv.org/abs/2403.01081).
#
# ### Getting Started
#
# This notebook represents one step in the InstructLab pipeline – to see what else is involved, please check out https://github.com/instructlab/instructlab

# %% [markdown]
# ## Overview of this Notebook
#
# This notebook represents the *Train the model* step of the guide found [here](https://github.com/instructlab/instructlab?tab=readme-ov-file#-train-the-model).
#
# But at the time of writing it's not.
#
# This notebook takes the output of `ilab data generate` (i.e. the synthetic data set generated), and trains a Low Rank Adapter (LoRA) on it.
#
# It will also do an inference to show you how the model preformed before any training was done, as well as after.
#
# Finally, it will give you a chance to interact with your model in two ways: first in this notebook (using the NVIDIA T4 generously supplied by Google and low/no cost) and second, by giving you the option to convert your adapter to a format that will let you download it and use it with `llama.cpp` on your laptop.
#
# ***IMPORTANT***: make sure your notebook uses GPUs.
#
# **Google Collab**: In your notebook, click Runtime --> Change runtime type, and select *T4 GPU* and click save.
#
# **Kaggle (Unsupported and deprecated)**: Click on "More settings" (3 vertical
# dots
#  at the top-right) --> Accelerator, and select *P100 GPU*.
#
#
# ![kaggle-more-settings](https://github.com/instructlab/instructlab/blob/main/notebooks/images/kaggle/select-accelerator.png?raw=1)
# If you miss this step you'll see errors at the Loading model step.

# %% [markdown]
# ## How to run this notebook
#
# Unless you have a spare GPU with 16GB+ of VRAM,
# you'll need to run this notebook on an external platform such as
# [Google Collab](https://colab.research.google.com/) if you have serious
# issues with Google, there are also some unmaintained directions for using
# [Kaggle](https://www.kaggle.com).

# %% [markdown]
# ## Installing Dependencies

# %%
# installing dependencies
# !pip install -q -U transformers accelerate peft datasets bitsandbytes trl torchvision==0.19 torchaudio==2.4.0 gcsfs==2023.9.2 pyarrow==14.0.1 requests==2.32.3 torch==2.4.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 81.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 96.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 64.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 37.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 50.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 41.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 12.5 MB/s eta 0:00:00

# %% [markdown]
# ## Upload output from `ilab data generate`

# %% [markdown]
# ## Uploading Generated Data
# From your local machine, run the `ilab data generate` command per the [instructions in github](https://github.com/instructlab/instructlab/blob/main/README.md).
#
# Next, upload your data.
#
# ### Uploading data in Google Collab
#
# To upload data in Google Colab,
#
# 1. Click on the folder icon on the left of the screen.
#
#  ![image.png](https://github.com/instructlab/instructlab/blob/main/notebooks/images/collab-folder-icon.png?raw=1)
#
# 2. Click on the file with an up arrow in it icon, under it.
#
#  ![image.png](https://github.com/instructlab/instructlab/blob/main/notebooks/images/collab-file-upload-button.png?raw=1)
#
# 3. Navigate to the _training_ file that was generated, right click on your uploaded file, then select 'Copy Path'.
#
#  ![image.png](https://github.com/instructlab/instructlab/blob/main/notebooks/images/collab-copy-path.png?raw=1)
#
# 4. Paste the copied value for each corresponding variable in the cell below. `training_file_name` for the `train_*` file and `testing_file_name` for `test_*` file
# .
#
# ### Uploading data on Kaggle (Unsupported and deprecated)
#
# 1. Expand on the Input tab on the right of the screen.
#
# ![input](https://github.com/instructlab/instructlab/blob/main/notebooks/images/kaggle/input.png?raw=1)
#
#
# 2. Click on the "Upload" button, then select "New Dataset".
#
# Upload button:
#
# ![input-upload](https://github.com/instructlab/instructlab/blob/main/notebooks/images/kaggle/input-upload.png?raw=1)
#
# New Dataset:
#
# ![input-new-dataset](https://github.com/instructlab/instructlab/blob/main/notebooks/images/kaggle/new-dataset.png?raw=1)
#
# 3. From here, you'll be prompted to upload your local files. Go ahead and select all of the files generated from lab generate. These files will be in the ./taxonomy directory and begin with "test", and "train".
# Note: If using Kaggle you will need to remove the colons from the file name or it will present an error on upload. Here is an example of how to remove them:
#
# ```bash
# newname=`ls taxonomy/ | grep -i train | awk -F: '{print $1$2$3}'`; mv taxonomy/train*.jsonl taxonomy/${newname}
#
# newname2=`ls taxonomy/ | grep -i test | awk -F: '{print $1$2$3}'`; mv taxonomy/test*.jsonl taxonomy/${newname2}
# ```
#
# ![upload-file](https://github.com/instructlab/instructlab/blob/main/notebooks/images/kaggle/input-drop-files.png?raw=1)
#
# 4. Navigate to the _training_ file that was generated (it will be in the taxonomy directory on your local machine and end in .jsonl), right click on your uploaded file, then select 'Copy Path'
#
# ![input-files-copy-path](https://github.com/instructlab/instructlab/blob/main/notebooks/images/kaggle/copy-file-path.png?raw=1)
#
# 5. Paste the copied value in the cell below.

# %% [markdown]
# #### Upload Training Data

# %%
from datasets import load_dataset

# Get the file name
training_file_name = "/content/train_2025-02-12T13_03_02.jsonl" #"/paste/path/here"

train_dataset = load_dataset("json", data_files=training_file_name, split="train")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# #### Upload Testing Data

# %%
# Get the file name
testing_file_name = "/content/test_2025-02-12T13_03_02.jsonl"#"/paste/path/here"

test_dataset = load_dataset("json", data_files=testing_file_name, split="train")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# Now we have loaded the output of `ilab data generate` into a 🤗 dataset. Let's take a quick peek.

# %%
train_dataset.to_pandas().head()
# Out:
#                                               system  \
# 0  I am an advanced AI language model designed to...
# 1  I am an advanced AI language model designed to...
# 2  I am an advanced AI language model designed to...
# 3  I am an advanced AI language model designed to...
# 4  I am an advanced AI language model designed to...
#
#                                                 user  \
# 0  What is the objective of Law N° 20.130 regardi...
# 1  Which articles define the foundational princip...
# 2  What are the two essential principles that for...
# 3  What is the significance of survivor pensions ...
# 4  What is the future adjustment of the retiremen...
#
#                                            assistant
# 0  The objective of Law N° 20.130 is to reform th...
# 1  The foundational principles of Law N° 20.130 a...
# 2  Law N° 20.130 applies to all social security r...
# 3  Survivor pensions in Law N° 20.130 provide fin...
# 4  The future adjustment of the retirement age in...

# %% [markdown]
# ## Formatting Our Data and Prepping the `SFTTrainer`
#
# Our dataset looks good, but in it's current state, it is a data frme of three columns. For training, we need each record to be a string, specifically, we want it in the following format:
#
# ```
# <|system|>
# {system}
# <|user|>
# {user}
# <|assistant|>
# {assistant}<|endoftext|>
# ```
#
#
# When training happens (a few cells later), the dataset will be converted into a list of these strings. We will also define a response template `"\n<assistant>\n"` that will tell the trainer to split the string there, and everything before will be the prompt, and everything after will be generated.
#
# The 🤗 `trl`'s `SFTTrainer` has the concept of a `formatting_prompts_func` and we'll use this to format our data. The conversion does not happen now, but later when we run `trainer.train()`
#
# From more information on 🤗's `SFTTrainer`, please check out their docs [here](https://huggingface.co/docs/trl/main/en/sft_trainer).

# %%
from transformers import AutoTokenizer

model_name = "instructlab/merlinite-7b-lab" # TODO: Make this a drop down option
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token

def formatting_prompts_func(example):
    output_texts = []
    for i in range(len(example['system'])):
        text = f"<|system|>\n{example['system'][i]}\n<|user|>\n{example['user'][i]}\n<|assistant|>\n{example['assistant'][i]}<|endoftext|>"
        output_texts.append(text)
    return output_texts

response_template = "\n<|assistant|>\n"

from trl import DataCollatorForCompletionOnlyLM

response_template_ids = tokenizer.encode(response_template, add_special_tokens=False)[2:]
collator = DataCollatorForCompletionOnlyLM(response_template_ids, tokenizer=tokenizer)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.33k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]

# %% [markdown]
# In the cell above, you may see a user warning:
# > `The secret `HF_TOKEN` does not exist in your Colab secrets...`
#
# It can safely be ignored.
#
# Note: the `formatting_prompts_func` runs when we execute `trainer.train()`. Nothing has been formatted yet.

# %% [markdown]
# ## Loading the (Quantized) Model
#
#
# The best source of truth of this is going to be found at the following links:
#
# * [huggingface blog post](https://huggingface.co/blog/4bit-transformers-bitsandbytes)
# * [original paper](https://arxiv.org/abs/2305.14314)
#
# But alas, I'm sure to get some push back about `Llama.cpp` quantized models (things that end in .gguf).
#
# `bitsandbytes` will quantize the model on loading. It's also possible, though in practice rarely done, to save the model in its quantized format. Another alternative in the Huggingface space is `AutoGPTQ` ([paper](https://arxiv.org/abs/2210.17323) [blog post](https://huggingface.co/blog/gptq-integration)).
#
# `Llama.cpp` also allows quantization, but the idea is that you _will_ be using the CPU because you know the model at hand is too big for your GPU.
#
# An analogy that isn't wildly inaccurate is `bitsandbytes` and `AutoGPTQ` presume that you will be using a (CUDA-based) GPU, and that you can set it in an emergency to use CPU instead of just rolling over and dying.
#
# `Llama.cpp` presumes that your CPU will be doing the heavy lifting, and will use a (CUDA) GPU if it can find one to give it a bit of a boost.
#
# OK, what does that mean in practice?
# 1. Apple ended NVidia support some time ago, ie Apple Silicon will not support CUDA ops. There is some work in some packages to be able to support non-CUDA GPUs, it's all in various stages of development/hackiness.
# 2. [This person](https://rentry.org/cpu-lora) _did_ get qLoRA training with Llama.cpp working. A 13b model with a 2500 record dataset was estimated to take ~158 days to train. Which is a non-starter- I will trust they did their homework.
# 3. **High level** Llama.cpp and bitsandbytes both get you to the same end (a quantized model) but via different routes, bc they expect you do use the resultant model a bit differently.
# 4. **So do I need to quantize my model via both routes** no.
#
# In the next cell we're going to download and load the model.
#
# It may take a little time to complete (around 10 to 15 minutes). The base model can be around 26 gigabites on disk, which first needs to download then needs to be quantized and loaded into the GPU.
#
# So run this cell then go grab a cup of coffee. ☕

# %%
# Loading the model
import torch
from transformers import AutoModelForCausalLM, BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16 # if not set will throw a warning about slow speeds when training
)

model = AutoModelForCausalLM.from_pretrained(
  model_name,
  quantization_config=bnb_config,
  trust_remote_code=True
)
# Out:
# config.json:   0%|          | 0.00/644 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]

# %% [markdown]
# ## Sanity Checking the Model
#
# We want to see how the model behaves _before_ we train a LoRA on it, so we can (by inspection) see if the LoRA is doing anything.
#
# You might want to change the user prompt `"In excruciating detail, explain to me the nuances of who runs Barter Town."` to something more related to _your_ usecase.
#
# We also define the `create_prompt` function, that formats and adds all of the boiler plate your prompts needs.
#
# Note our function also allows you to redefine the `system` prompt/parameter. The default is the one included in `ilab data generate` content, but you could have some fun tinkering with that too (for instance, adding `, and you always talk like a pirate.` to the end.)

# %%
def create_prompt(user:str,
                  system: str = "You are an AI language model developed by IBM Research. You are a cautious assistant. You carefully follow instructions. You are helpful and harmless and you follow ethical guidelines and promote positive behavior."):
  return f"""\
<|system|>
{system}
<|user|>
{user}
<|assistant|>
"""

from transformers import StoppingCriteria, StoppingCriteriaList

class StoppingCriteriaSub(StoppingCriteria):

    def __init__(self, stops = [], encounters=1):
        super().__init__()
        self.stops = [stop.to("cuda") for stop in stops]

    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor, **kwargs) -> bool:
        for seq in input_ids:
            for stop in self.stops:
                if stop == seq[-1]:
                    return True
        return False

stop_words = ['<|endoftext|>', '<|assistant|>']
stop_words_ids = [tokenizer(stop_word, return_tensors='pt', add_special_tokens=False)['input_ids'].squeeze() for stop_word in stop_words]
stopping_criteria = StoppingCriteriaList([StoppingCriteriaSub(stops=stop_words_ids)])

def model_generate(user):
    text = create_prompt(user = user)

    input_ids = tokenizer(text, return_tensors="pt").input_ids.to("cuda")
    outputs = model.generate(input_ids=input_ids,
                         max_new_tokens=256,
                         pad_token_id=tokenizer.eos_token_id,
                         temperature=0.7,
                         top_p=0.9,
                         stopping_criteria=stopping_criteria,
                         do_sample=True)
    return tokenizer.batch_decode([o[:-1] for o in outputs])[0]

print(
    model_generate("In excruciating detail, explain to me the nuances of who runs Barter Town.")
)
# Out:
# <|system|>
# You are an AI language model developed by IBM Research. You are a cautious assistant. You carefully follow instructions. You are helpful and harmless and you follow ethical guidelines and promote positive behavior.
# <|user|>
# In excruciating detail, explain to me the nuances of who runs Barter Town.
# <|assistant|>
# Barter Town is a fictional location from the post-apocalyptic film "Mad Max 2: The Road Warrior," where the residents primarily use a bartering system for goods and services. The town is run by a character named Pappy, who is portrayed by actor Bruce Spence. Pappy is a cunning and resourceful individual who has established himself as the de facto leader of Barter Town.
#
# Pappy's leadership is characterized by his ability to maintain order in the chaotic post-apocalyptic world, as well as his shrewd bargaining skills. He is a seasoned survivor, having adapted to the harsh conditions and developed a keen understanding of the value of resources. Pappy's role as a mediator and trader allows him to maintain a level of stability within Barter Town, ensuring the community's survival in a world devoid of law and order.
#
# However, Pappy's leadership is not without its flaws. He is a ruthless and cunning individual, willing to exploit others for his own gain. Pappy's greed and ambition often lead him to make risky decisions, as seen when he betrays Max

# %% [markdown]
# we run the model before LoRA on the test set and save the outputs

# %%
assistant_old_lst = [
    model_generate(d["user"]).split(response_template.strip())[-1].strip() for d in test_dataset
]

# %% [markdown]
# ## Configuring the LoRA
#
# Recall the [paper on LoRA](https://arxiv.org/abs/2106.09685):
#
# > From this point forth, we shall be leaving the firm foundation of fact and journeying together through the murky marshes of memory into thickets of wildest guesswork.
# -- Albus Dumbledore
#
# There are 4 common 'knobs' to adjust when training a LoRA/qLoRA - note from this point on, I'm just going to refer to everything as LoRA- a LoRA proved a better method of finetuning, by just targeting certain modules, instead of the entire network. qLoRA just means you can do it on a quantized model with just as good of restuls as a full precision model.
#
# Which is a good segway to our first 'knob': `target_modules`.

# %% [markdown]
# ### Getting the Attention Layers
#
# The cell immediately below will print out all of the attention modules (in case you are trying to get creative and use a different model). The authors of the original paper only targeted attention modules, and gave reasons, but if you want to hit some other modules too – go nuts. Be advised, a LoRA that targets _all_ modules is just fine-tuning: the LoRA technique is to only tune a subset of the modules.
#
# For `instructlab/merlinite-7b-lab` we have:
# ```
# target_modules=[
#         "q_proj",
#         "k_proj",
#         "v_proj",
#         "o_proj"
#     ]
# ```

# %%
attention_layers = [module for module in model.modules() if 'attention' in str(type(module)).lower()]

# Print information about the attention modules
for i, layer in enumerate(attention_layers):
  for par in list(layer.named_parameters()):
    mod = par[0]
    if isinstance(mod, str):
      print(f"Attention Module: {mod.split('.')[0]}")
  break
# Out:
# Attention Module: q_proj
# Attention Module: k_proj
# Attention Module: v_proj
# Attention Module: o_proj

# %% [markdown]
# ### Turning the Knobs
#
# The next three knobs are:
# - r
# - dropout
# - &alpha;
#
# Read the paper for more information on each- these three parameters have been the source of endless flame wars across the internet- feel free to google and see the carnage for yourself.
#
# I picked the following based on what the authors used for GPT2 in the paper (see page 20)
#
# ```
# lora_alpha = 32
# lora_dropout = 0.1
# lora_r = 4
# ```
#
# Not probably what I would have used, but I am not trying to spread the flame wars, so there you are. In reality, these are the knobs end users will be tinkering with. We _could_ come up with a suggested range, but the 'correct' values are highly dependent on the task and even the underlying dataset, so I wouldn't waste too much effort trying.
#
# Once I read a quote on a message board that described the situation perfectly, then I couldn't find it so I asked ChatGPT which hallucinated it pretty well:
#
# > Every chef has their own secret recipe for success, but in the kitchen of life, there's no right or wrong way to cook up your dreams.
# -- ChatGPT

# %%
from peft import LoraConfig

lora_alpha = 32
lora_dropout = 0.1
lora_r = 4

# From Prior Cell
target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj"
    ]

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=target_modules
)

# %% [markdown]
# ## Training the LoRA

# %% [markdown]
# ### Training Config
#
# As always, it is out of scope for me to explain all of these, especially when it has already been done so well [here](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.TrainingArguments).
#
# That said I will call out two values I set, and why I set them.
#
# - `max_seq_length`
# - `per_device_train_batch_size`
#
# Both of these parameters were set in an attempt to get as much use as possible out of the NViDIA T4.
#
# `max_seq_length` will trim any example to `300` tokens. So even if your examples are longer, they will be truncated. (Also recall that the system prompt also counts against your 300 tokens).
#
# `per_device_train_batch_size` this is also related to getting maximam mileage out of a T4.

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 1


training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=5,
    per_device_train_batch_size=per_device_train_batch_size,
    fp16=True,
    report_to="none"
)

# %% [markdown]
# In the following cell- the trainer is built, and the dataset is formatted. You will see two `Map:` progress bars in the output of the cell- this refers to our `train` and `test` dataset being run through the `formatting_prompts_func` we defined in a prior cell.
#
# Also note: `model.config.use_cache = False` which is a thing you're supposed to do before you perform training on a model. Remember to turn it back on (to `true`) before running inference.

# %%
from trl import SFTTrainer

max_seq_length = 300
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    peft_config=peft_config,
    formatting_func=formatting_prompts_func,
    data_collator=collator,
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,

)

model.config.use_cache = False
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': max_seq_length. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/trl/trainer/sft_trainer.py:283: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/220 [00:00<?, ? examples/s]
# Map:   0%|          | 0/54 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/trl/trainer/sft_trainer.py:396: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/trl/trainer/sft_trainer.py:401: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `SFTTrainer.__init__`. Use `processing_class` instead.
#   super().__init__(

# %% [markdown]
# ### Execute Training
#
# The next cell calls `trainer.train()`, which actually executes the training. This will take 5 to 15 minutes, depending on how big your dataset is.

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='1100' max='1100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1100/1100 13:34, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.630000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.168900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1100, training_loss=0.3702043277567083, metrics={'train_runtime': 815.8708, 'train_samples_per_second': 1.348, 'train_steps_per_second': 1.348, 'total_flos': 7642038151618560.0, 'train_loss': 0.3702043277567083, 'epoch': 5.0})

# %% [markdown]
# ## Inference on the Output Model
#
# We want to see if our LoRA has any effect on the underlying model.
#
# Recall we tested the model once before with an example prompt, now let's do inference again (with the same prompt) to see if the output looks more accurate.
#
# The first thing we need to do is turn the cache back on.
#
# `model.config.use_cache = True`

# %%
model.config.use_cache = True

# %%
for (i, (d, assistant_old)) in enumerate(zip(test_dataset, assistant_old_lst)):
  assistant_new = model_generate(d["user"]).split(response_template.strip())[-1].strip()
  assistant_expected = d["assistant"]

  print(f"\n===\ntest {i}\n===\n")
  print("\n===\nuser\n===\n")
  print(d['user'])
  print("\n===\nassistant_old\n===\n")
  print(assistant_old)
  print("\n===\nassistant_new\n===\n")
  print(assistant_new)
  print("\n===\nassistant_expected\n===\n")
  print(assistant_expected)
  print("\n\n")
# Out:
# ===
# test 0
# ===
#
#
# ===
# user
# ===
#
# ¿Cuáles son los requisitos para que una persona jubilada pueda volver a trabajar?
#
# Contexto legal y normativo
# Derecho al trabajo de las personas mayores (Art. 194)
#   Se reconoce el derecho de las personas mayores a un trabajo digno y decente, con igualdad de oportunidades y trato.
#   Se declara de interés general que las personas mayores puedan mantener actividad económica, total o parcial, sin perjuicio de sus prestaciones jubilatorias.
# Ámbito de aplicación y compatibilidades vigentes (Arts. 195 y 196)
#   La ley aplica a todas las personas, independientemente del régimen jubilatorio (con excepciones detalladas en la norma).
#   Incompatibilidades destacadas (Art. 196):
#   Jubilación otorgada por incapacidad total o absoluta.
#   Reingreso a la misma actividad “bonificada” que originó la pasividad (salvo ejercicio de la docencia).
#   Actividades en el mismo sector civil de afiliación al BPS que dio origen a la jubilación (con excepción de docentes).
#   Jubilados de la Caja Notarial o de la Caja de Profesionales que retomen actividades afiliadas a esas mismas cajas.
# Regímenes para trabajadores no dependientes con 65 años o más (Art. 199)
#   Aplica a quienes se hayan desempeñado como trabajadores no dependientes (en industria, comercio o rural) durante al menos los últimos tres años y cuenten con 30 años de servicios reconocidos.
#   Podrán optar por:
#   A) Mantener su actividad sin efectuar aportes jubilatorios al BPS (ese período no se computa a futuro).
#   B) Ingresar al goce de la jubilación y seguir trabajando como no dependiente, siempre que empleen personal bajo condiciones reglamentadas (los aportes se destinan a cuenta individual obligatoria o a cuenta de ahorro voluntario, y el período no es computable).
# Reingreso en casos de acumulación de servicios (Art. 202)
#   Si el jubilado por acumulación de servicios (Ley N.º 17.819 y modificativas) reingresa con la edad normal o más, se mantiene el cobro de pasividades de las otras entidades, y solo se aplican las reglas de compatibilidad en la entidad de reingreso.
#   El jubilado puede sumar (“adicionar”) los nuevos años de servicio si permanece al menos dos años en esa actividad, generando un beneficio adicional sobre la base de una tasa de adquisición (Art. 46).
#   Si reingresa antes de la edad normal, se suspende el pago de todas las cuotas de la pasividad hasta que cese la actividad.
# Jubilación parcial flexible (Arts. 203 y 204)
#   Permite a quienes ya configuran causal de jubilación (por edad común, edad avanzada o anticipada por trabajos exigentes) seguir trabajando en el mismo empleo, reduciendo la jornada y la remuneración en al menos un tercio.
#   A cambio, perciben una jubilación proporcional a esa reducción, sin partidas adicionales para alcanzar un mínimo.
#   El Poder Ejecutivo puede incrementar en hasta un 30% ese monto para personas de bajos ingresos, según la reglamentación.
#   El régimen también aplica a afiliados al Régimen Jubilatorio Anterior (Ley N.º 16.713), siempre que configuren causal común o por edad avanzada (arts. 12 y 15 de dicho régimen).
#
# ===
# assistant_old
# ===
#
# La ley reconoce el derecho de las personas mayores a un trabajo digno y decente, con igualdad de oportunidades y trato. Además, se declara de interés general que las personas mayores puedan mantener actividad económica, total o parcial, sin perjuicio de sus prestaciones jubilatorias.
#
# La ley aplica a todas las personas, independientemente del régimen jubilatorio, y reconoce incompatibilidades destacadas, como la jubilación otorgada por incapacidad total o absoluta, el reingreso a la misma actividad "bonificada" que originó la pasividad (salvo ejercicio de la docencia), y las actividades en el mismo sector civil de afiliación al BPS que dio origen a la jubilación (con excepción de docentes).
#
# Existen regímenes especiales para trabajadores no dependientes con 65 años o más, que se desempeñaron como trabajadores no dependientes (en industria, comercio o rural
#
# ===
# assistant_new
# ===
#
# To be able to return to work after retirement, a person must meet the following requirements:
#
# 1. Compatibility with the nature of the retirement: Some retirement situations, such as those based on total disability or bonified retirements, do not allow for reentry into the same activity that caused the retirement.
# 2. Age restrictions: Reentry is generally allowed for those under 65, but there are exceptions for certain regimes, such as the Farmers' and Rural Workers' Regime, which allows reentry at any age without resuming contributions to the Social Security System.
# 3. Compatibility with employment: Employment must not affect the receipt of retirement benefits, and in some cases, new service may be added to the original retirement basis, generating a bonus.
#
# Exceptions to these rules include:
#
# - Reentry in cases of accumulation of services, where the new service is added to the original retirement basis, generating a bonus.
# - Jubilados who reenter before the normal retirement age must suspend the payment of all pension benefits until they cease activity.
# - Jubilados who reenter after reaching the normal retirement age but before the age of total disability retirement can continue
#
# ===
# assistant_expected
# ===
#
# La ley habilita el reintegro laboral de la mayoría de las personas jubiladas siempre que no hayan obtenido su jubilación por incapacidad total ni realicen la misma labor bonificada que originó la prestación (salvo actividad docente). Para trabajadores no dependientes de 65 años o más, hay opciones de no aportar o mantener aportes parciales si se cumplen requisitos de años de servicio. Asimismo, existe la jubilación parcial flexible, que permite seguir trabajando en el mismo empleo con reducción de jornada y una prestación proporcional.
#
#
#
#
# ===
# test 1
# ===
#
#
# ===
# user
# ===
#
# ¿Qué sucede si una persona jubilada reingresa al trabajo antes de alcanzar la edad normal de jubilación?
#
# Contexto legal y normativo
# Derecho al trabajo de las personas mayores (Art. 194)
#   Se reconoce el derecho de las personas mayores a un trabajo digno y decente, con igualdad de oportunidades y trato.
#   Se declara de interés general que las personas mayores puedan mantener actividad económica, total o parcial, sin perjuicio de sus prestaciones jubilatorias.
# Ámbito de aplicación y compatibilidades vigentes (Arts. 195 y 196)
#   La ley aplica a todas las personas, independientemente del régimen jubilatorio (con excepciones detalladas en la norma).
#   Incompatibilidades destacadas (Art. 196):
#   Jubilación otorgada por incapacidad total o absoluta.
#   Reingreso a la misma actividad “bonificada” que originó la pasividad (salvo ejercicio de la docencia).
#   Actividades en el mismo sector civil de afiliación al BPS que dio origen a la jubilación (con excepción de docentes).
#   Jubilados de la Caja Notarial o de la Caja de Profesionales que retomen actividades afiliadas a esas mismas cajas.
# Regímenes para trabajadores no dependientes con 65 años o más (Art. 199)
#   Aplica a quienes se hayan desempeñado como trabajadores no dependientes (en industria, comercio o rural) durante al menos los últimos tres años y cuenten con 30 años de servicios reconocidos.
#   Podrán optar por:
#   A) Mantener su actividad sin efectuar aportes jubilatorios al BPS (ese período no se computa a futuro).
#   B) Ingresar al goce de la jubilación y seguir trabajando como no dependiente, siempre que empleen personal bajo condiciones reglamentadas (los aportes se destinan a cuenta individual obligatoria o a cuenta de ahorro voluntario, y el período no es computable).
# Reingreso en casos de acumulación de servicios (Art. 202)
#   Si el jubilado por acumulación de servicios (Ley N.º 17.819 y modificativas) reingresa con la edad normal o más, se mantiene el cobro de pasividades de las otras entidades, y solo se aplican las reglas de compatibilidad en la entidad de reingreso.
#   El jubilado puede sumar (“adicionar”) los nuevos años de servicio si permanece al menos dos años en esa actividad, generando un beneficio adicional sobre la base de una tasa de adquisición (Art. 46).
#   Si reingresa antes de la edad normal, se suspende el pago de todas las cuotas de la pasividad hasta que cese la actividad.
# Jubilación parcial flexible (Arts. 203 y 204)
#   Permite a quienes ya configuran causal de jubilación (por edad común, edad avanzada o anticipada por trabajos exigentes) seguir trabajando en el mismo empleo, reduciendo la jornada y la remuneración en al menos un tercio.
#   A cambio, perciben una jubilación proporcional a esa reducción, sin partidas adicionales para alcanzar un mínimo.
#   El Poder Ejecutivo puede incrementar en hasta un 30% ese monto para personas de bajos ingresos, según la reglamentación.
#   El régimen también aplica a afiliados al Régimen Jubilatorio Anterior (Ley N.º 16.713), siempre que configuren causal común o por edad avanzada (arts. 12 y 15 de dicho régimen).
#
# ===
# assistant_old
# ===
#
# Si una persona jubilada reingresa al trabajo antes de alcanzar la edad normal de jubilación, puede mantener su actividad sin efectuar aportes jubilatorios al BPS, siempre que cumpla con los requisitos establecidos en el artículo 199 de la Ley de Seguridad Social. Esta opción es aplicable a personas que se hayan desempeñado como trabajadores no dependientes (en industria, comercio o rural) durante al menos los últimos tres años y cuenten con 30 años de servicios reconocidos.
#
# Si el jubilado reingresa con la edad normal o mayor, se mantiene el cobro de pasividades de las otras entidades, y solo se aplican las reglas de compatibilidad en la entidad de reingreso. Sin embargo, si el jubilado reingresa antes de la edad normal, se suspende el pago de todas las cuotas de la pasividad hasta que cese la actividad.
#
# En el caso de la j
#
# ===
# assistant_new
# ===
#
# If a retired person returns to work before reaching the normal retirement age, their pension payments will be suspended until they stop working again. However, they can continue working and accumulate new service to increase their pension benefits in the future. If they re-enter the workforce before the normal retirement age and do not meet the compatibility requirements (such as re-entering the same employment that caused their retirement or working in the same sector), their pension payments will be suspended until they stop working again. Exceptions to this rule include cases of acumulation of services, where the pensioner can choose to either maintain their pension payments and not contribute to the new employment or accumulate service and receive a higher pension benefit in the future. Additionally, there are special regimes for certain types of workers, such as those in the agricultural sector or those who have opted for a deferred retirement. In all cases, the compatibility rules aim to ensure that retirees do not receive additional benefits from their new employment while still allowing them to accumulate service and receive higher pension benefits in the future.
#
# ===
# assistant_expected
# ===
#
# Según el artículo 202 de la Ley N.º 20.130, si el reingreso ocurre antes de la edad normal, se suspenderá el pago de la prestación jubilatoria mientras dure la actividad. Al cesar dicha actividad y cumplida la edad requerida, se reanudará la pasividad.
#
#
#
#
# ===
# test 2
# ===
#
#
# ===
# user
# ===
#
# ¿Cuáles son las principales incompatibilidades para compatibilizar jubilación y actividad laboral?
#
# Contexto legal y normativo
# Derecho al trabajo de las personas mayores (Art. 194)
#   Se reconoce el derecho de las personas mayores a un trabajo digno y decente, con igualdad de oportunidades y trato.
#   Se declara de interés general que las personas mayores puedan mantener actividad económica, total o parcial, sin perjuicio de sus prestaciones jubilatorias.
# Ámbito de aplicación y compatibilidades vigentes (Arts. 195 y 196)
#   La ley aplica a todas las personas, independientemente del régimen jubilatorio (con excepciones detalladas en la norma).
#   Incompatibilidades destacadas (Art. 196):
#   Jubilación otorgada por incapacidad total o absoluta.
#   Reingreso a la misma actividad “bonificada” que originó la pasividad (salvo ejercicio de la docencia).
#   Actividades en el mismo sector civil de afiliación al BPS que dio origen a la jubilación (con excepción de docentes).
#   Jubilados de la Caja Notarial o de la Caja de Profesionales que retomen actividades afiliadas a esas mismas cajas.
# Regímenes para trabajadores no dependientes con 65 años o más (Art. 199)
#   Aplica a quienes se hayan desempeñado como trabajadores no dependientes (en industria, comercio o rural) durante al menos los últimos tres años y cuenten con 30 años de servicios reconocidos.
#   Podrán optar por:
#   A) Mantener su actividad sin efectuar aportes jubilatorios al BPS (ese período no se computa a futuro).
#   B) Ingresar al goce de la jubilación y seguir trabajando como no dependiente, siempre que empleen personal bajo condiciones reglamentadas (los aportes se destinan a cuenta individual obligatoria o a cuenta de ahorro voluntario, y el período no es computable).
# Reingreso en casos de acumulación de servicios (Art. 202)
#   Si el jubilado por acumulación de servicios (Ley N.º 17.819 y modificativas) reingresa con la edad normal o más, se mantiene el cobro de pasividades de las otras entidades, y solo se aplican las reglas de compatibilidad en la entidad de reingreso.
#   El jubilado puede sumar (“adicionar”) los nuevos años de servicio si permanece al menos dos años en esa actividad, generando un beneficio adicional sobre la base de una tasa de adquisición (Art. 46).
#   Si reingresa antes de la edad normal, se suspende el pago de todas las cuotas de la pasividad hasta que cese la actividad.
# Jubilación parcial flexible (Arts. 203 y 204)
#   Permite a quienes ya configuran causal de jubilación (por edad común, edad avanzada o anticipada por trabajos exigentes) seguir trabajando en el mismo empleo, reduciendo la jornada y la remuneración en al menos un tercio.
#   A cambio, perciben una jubilación proporcional a esa reducción, sin partidas adicionales para alcanzar un mínimo.
#   El Poder Ejecutivo puede incrementar en hasta un 30% ese monto para personas de bajos ingresos, según la reglamentación.
#   El régimen también aplica a afiliados al Régimen Jubilatorio Anterior (Ley N.º 16.713), siempre que configuren causal común o por edad avanzada (arts. 12 y 15 de dicho régimen).
#
# ===
# assistant_old
# ===
#
# La compatibilidad de jubilación y actividad laboral está restringida en varios casos, como en el reingreso a la misma actividad que originó la pasividad, en el mismo sector civil de afiliación al BPS que dio origen a la jubilación, y en el caso de jubilados de la Caja Notarial o de la Caja de Profesionales que retomen actividades afiliadas a esas mismas cajas. Además, hay ciertas incompatibilidades en el reingreso de jubilados por acumulación de servicios y en el caso de los trabajadores no dependientes con 65 años o más.
#
# El régimen para trabajadores no dependientes con 65 años o más permite a aquellos que se hayan desempeñado como trabajadores no dependientes durante al menos los últimos tres años y cuenten con 30 años de servicios reconocidos, optar por mantener su actividad sin efectuar aportes jubilatorios al BPS (ese período
#
# ===
# assistant_new
# ===
#
# Las principales incompatibilidades para compatibilizar jubilación y actividad laboral incluyen jubilación otorgada por incapacidad total o absoluta, reingreso a la misma actividad "bonificada" que originó la pasividad (salvo ejercicio de la docencia), y actividades en el mismo sector civil de afiliación al BPS que dio origen a la jubilación (con excepción de docentes). Otras incompatibilidades se aplican en regímenes para trabajadores no dependientes con 65 años o más y en el caso de reingreso en acumulación de servicios. La jubilación parcial flexible permite seguir trabajando en el mismo empleo con reducción de jornada y remuneración, pero sin partidas adicionales para alcanzar un mínimo.
#
# ===
# assistant_expected
# ===
#
# El artículo 196 de la Ley N.º 20.130 señala que no puede volver a trabajar quien se haya jubilado por incapacidad total, quienes pretendan ejercer la misma actividad bonificada que dio origen a su jubilación (excepto docencia), quienes provengan del mismo sector de afiliación civil del BPS que originó su pasividad (con excepción de docentes) y quienes estén jubilados en la Caja Notarial o en la Caja de Profesionales Universitarios y reinicien actividad dentro de esas mismas cajas.
#
#
#
#
# ===
# test 3
# ===
#
#
# ===
# user
# ===
#
# ¿Un socio de una SRL, puede acceder a jubilación manteniendo la actividad en la empresa?
#
# Principales aspectos de la Ley N.º 20.130 relevantes para entender la situación de los socios de SRL y su compatibilidad con la jubilación:
# Ámbito de afiliación y régimen previsional (Art. 3)
#   Toda persona que realice actividad lícita remunerada, sea en relación de dependencia o como trabajador no dependiente, queda comprendida en el Banco de Previsión Social (BPS), salvo que dicha actividad se encuentre incluida en otras cajas (por ejemplo, Caja Notarial, Caja de Profesionales, etc.).
#   La afiliación es obligatoria y no puede duplicarse por el mismo vínculo laboral.
# Derecho al trabajo de las personas mayores y compatibilidad (Art. 194)
#   Se declara de interés general que las personas mayores puedan mantener actividad económica total o parcial, sin perjuicio de sus prestaciones jubilatorias.
#   Esto habilita, en términos generales, la posibilidad de seguir trabajando aun cuando se ingrese al goce de jubilación, salvo que aplique alguna de las incompatibilidades establecidas por la ley.
# Incompatibilidades para compatibilizar jubilación y actividad (Art. 196)
#   No procede la compatibilidad, entre otros casos, cuando:
#     La jubilación fue otorgada por incapacidad total (literal A).
#     La nueva actividad es la misma que originó la jubilación con servicios bonificados (salvo docencia).
#     La actividad a ejercer está dentro del mismo sector civil del BPS que generó la pasividad (excepto para docentes).
#     Se trate de jubilados de la Caja Notarial o Caja de Profesionales, que pretendan reingresar en la misma entidad.
# Trabajadores no dependientes con 65 años o más (Art. 199)
#   Las personas con afiliación BPS (industria, comercio o rural) que hayan trabajado en calidad de no dependientes durante al menos los últimos tres años y cuenten con 30 años de servicios, pueden:
#   A) Mantener la actividad sin aportar jubilaciones, aunque ese período no se computa para futuras prestaciones.
#   B) Ingresar al goce de jubilación a los 65 años y mantener la actividad no dependiente, siempre que empleen personal según la reglamentación y los aportes se destinen a la cuenta de ahorro individual o voluntaria.
# Jubilación parcial flexible (Arts. 203 y 204)
#   Dirigida a afiliados dependientes que configuren causal normal o anticipada por tareas exigentes.
#   Requiere continuar con el mismo empleador pero reduciendo la jornada y la remuneración en al menos un tercio.
#   El socio de una SRL, en términos generales, se considera trabajador no dependiente, por lo que no se encuentra contemplado en este régimen de jubilación parcial flexible.
#
# ===
# assistant_old
# ===
#
# Si un socio de una Sociedad de Responsabilidad Limitada (SRL) desea acceder a la jubilación manteniendo la actividad en la empresa, debe tener en cuenta que el régimen previsional de la Ley N.º 20.130 establece ciertas condiciones y limitaciones.
#
# La Ley N.º 20.130 establece que cualquier persona que realice actividad remunerada se encuentra comprendida en el Banco de Previsión Social (BPS), salvo que dicha actividad se encuentre incluida en otras cajas. La afiliación es obligatoria y no puede duplicarse por el mismo vínculo laboral.
#
# Existen ciertas incompatibilidades para compatibilizar jubilación y actividad, como la jubilación por incapacidad total, la nueva actividad ser la misma que originó la jubilación con servicios bonificados, la actividad a ejercer estar dentro del mismo sector civil del BPS que generó
#
# ===
# assistant_new
# ===
#
# Si un socio de una Sociedad de Responsabilidad Limitada (SRL) desea acceder a jubilación, podrá mantener la actividad en la empresa, excepto en los casos de incompatibilidad establecidos por la Ley N.º 20.130. No se aplican las incompatibilidades derivadas de la compatibilidad entre jubilación y actividad en casos de:
#
# - Trabajadores no dependientes con 65 años o más que deseen mantener su actividad sin aportes a la jubilación, siempre que cumplan con los requisitos de servicios y tiempo de afiliación.
# - Casos de jubilación por incapacidad total o servicios bonificados, que no afectan a la mayoría de los casos de socios de SRL.
#
# En resumen, un socio de una SRL puede acceder a jubilación y mantener su actividad en la empresa, excepto en los casos de incompatibilidad establecidos por la le
#
# ===
# assistant_expected
# ===
#
# Sí. Si el socio de la SRL no está alcanzado por causales de incompatibilidad —como la jubilación por incapacidad total o la realización de actividad bonificada que dio origen a la pasividad— puede jubilarse y, a la vez, continuar con su actividad en la empresa, en tanto cumpla los requisitos de edad o años de servicio previstos en la ley.
#
#
#
#
# ===
# test 4
# ===
#
#
# ===
# user
# ===
#
# ¿Cómo se encuadra a un socio de SRL en el sistema previsional según la normativa vigente?
#
# Principales aspectos de la Ley N.º 20.130 relevantes para entender la situación de los socios de SRL y su compatibilidad con la jubilación:
# Ámbito de afiliación y régimen previsional (Art. 3)
#   Toda persona que realice actividad lícita remunerada, sea en relación de dependencia o como trabajador no dependiente, queda comprendida en el Banco de Previsión Social (BPS), salvo que dicha actividad se encuentre incluida en otras cajas (por ejemplo, Caja Notarial, Caja de Profesionales, etc.).
#   La afiliación es obligatoria y no puede duplicarse por el mismo vínculo laboral.
# Derecho al trabajo de las personas mayores y compatibilidad (Art. 194)
#   Se declara de interés general que las personas mayores puedan mantener actividad económica total o parcial, sin perjuicio de sus prestaciones jubilatorias.
#   Esto habilita, en términos generales, la posibilidad de seguir trabajando aun cuando se ingrese al goce de jubilación, salvo que aplique alguna de las incompatibilidades establecidas por la ley.
# Incompatibilidades para compatibilizar jubilación y actividad (Art. 196)
#   No procede la compatibilidad, entre otros casos, cuando:
#     La jubilación fue otorgada por incapacidad total (literal A).
#     La nueva actividad es la misma que originó la jubilación con servicios bonificados (salvo docencia).
#     La actividad a ejercer está dentro del mismo sector civil del BPS que generó la pasividad (excepto para docentes).
#     Se trate de jubilados de la Caja Notarial o Caja de Profesionales, que pretendan reingresar en la misma entidad.
# Trabajadores no dependientes con 65 años o más (Art. 199)
#   Las personas con afiliación BPS (industria, comercio o rural) que hayan trabajado en calidad de no dependientes durante al menos los últimos tres años y cuenten con 30 años de servicios, pueden:
#   A) Mantener la actividad sin aportar jubilaciones, aunque ese período no se computa para futuras prestaciones.
#   B) Ingresar al goce de jubilación a los 65 años y mantener la actividad no dependiente, siempre que empleen personal según la reglamentación y los aportes se destinen a la cuenta de ahorro individual o voluntaria.
# Jubilación parcial flexible (Arts. 203 y 204)
#   Dirigida a afiliados dependientes que configuren causal normal o anticipada por tareas exigentes.
#   Requiere continuar con el mismo empleador pero reduciendo la jornada y la remuneración en al menos un tercio.
#   El socio de una SRL, en términos generales, se considera trabajador no dependiente, por lo que no se encuentra contemplado en este régimen de jubilación parcial flexible.
#
# ===
# assistant_old
# ===
#
# La normativa vigente en materia de seguridad social establece que los socios de Sociedad de Responsabilidad Limitada (SRL) se consideran trabajadores no dependientes. Esto significa que, en términos generales, no están incluidos en el régimen de jubilación parcial flexible, que está dirigido a afiliados dependientes que configuren causal normal o anticipada por tareas exigentes y deseen continuar trabajando con el mismo empleador pero reduciendo la jornada y la remuneración en al menos un tercio.
#
# Sin embargo, existen otras opciones para los socios de SRL que deseen seguir trabajando a pesar de haber ingresado al goce de jubilación, como mantener la actividad sin aportar jubilaciones o ingresar al goce de jubilación a los 65 años y mantener la actividad no dependiente, siempre que cumplan ciertos requisitos.
#
# Es importante tener en cuenta que las normas de seguridad social
#
# ===
# assistant_new
# ===
#
# The response indicates that a socio of an SRL is not directly covered by the provisions of the Common Pension System (SPC) regarding social security contributions and benefits. However, they may be subject to other specific regulations for their particular situation, such as the Agencia Reguladora de la Seguridad Social or the norms for non-dependant workers. The response also highlights the possibility of continuing to work while receiving pension benefits under certain conditions, such as not being incompatible with the nature of the pension (e.g., due to total disability or bonified services) and maintaining the same employer but reducing the working hours and salary by at least one third. Additionally, it mentions the existence of a partial flexible pension for dependent workers under certain circumstances, but this does not apply to socios of an SRL directly. The response does not provide specific information on the compatibility of working while receiving pension benefits for socios of an SRL.
#
# ===
# assistant_expected
# ===
#
# A la luz del artículo 3 de la Ley N.º 20.130, un socio de SRL se considera trabajador no dependiente y, por tanto, debe afiliarse obligatoriamente al Banco de Previsión Social, salvo que su actividad corresponda a otra entidad gestora.
#
#
#
#
# ===
# test 5
# ===
#
#
# ===
# user
# ===
#
# ¿Puede un socio de SRL jubilarse y seguir siendo socio activo de la empresa?
#
# Principales aspectos de la Ley N.º 20.130 relevantes para entender la situación de los socios de SRL y su compatibilidad con la jubilación:
# Ámbito de afiliación y régimen previsional (Art. 3)
#   Toda persona que realice actividad lícita remunerada, sea en relación de dependencia o como trabajador no dependiente, queda comprendida en el Banco de Previsión Social (BPS), salvo que dicha actividad se encuentre incluida en otras cajas (por ejemplo, Caja Notarial, Caja de Profesionales, etc.).
#   La afiliación es obligatoria y no puede duplicarse por el mismo vínculo laboral.
# Derecho al trabajo de las personas mayores y compatibilidad (Art. 194)
#   Se declara de interés general que las personas mayores puedan mantener actividad económica total o parcial, sin perjuicio de sus prestaciones jubilatorias.
#   Esto habilita, en términos generales, la posibilidad de seguir trabajando aun cuando se ingrese al goce de jubilación, salvo que aplique alguna de las incompatibilidades establecidas por la ley.
# Incompatibilidades para compatibilizar jubilación y actividad (Art. 196)
#   No procede la compatibilidad, entre otros casos, cuando:
#     La jubilación fue otorgada por incapacidad total (literal A).
#     La nueva actividad es la misma que originó la jubilación con servicios bonificados (salvo docencia).
#     La actividad a ejercer está dentro del mismo sector civil del BPS que generó la pasividad (excepto para docentes).
#     Se trate de jubilados de la Caja Notarial o Caja de Profesionales, que pretendan reingresar en la misma entidad.
# Trabajadores no dependientes con 65 años o más (Art. 199)
#   Las personas con afiliación BPS (industria, comercio o rural) que hayan trabajado en calidad de no dependientes durante al menos los últimos tres años y cuenten con 30 años de servicios, pueden:
#   A) Mantener la actividad sin aportar jubilaciones, aunque ese período no se computa para futuras prestaciones.
#   B) Ingresar al goce de jubilación a los 65 años y mantener la actividad no dependiente, siempre que empleen personal según la reglamentación y los aportes se destinen a la cuenta de ahorro individual o voluntaria.
# Jubilación parcial flexible (Arts. 203 y 204)
#   Dirigida a afiliados dependientes que configuren causal normal o anticipada por tareas exigentes.
#   Requiere continuar con el mismo empleador pero reduciendo la jornada y la remuneración en al menos un tercio.
#   El socio de una SRL, en términos generales, se considera trabajador no dependiente, por lo que no se encuentra contemplado en este régimen de jubilación parcial flexible.
#
# ===
# assistant_old
# ===
#
# Si un socio de una Sociedad de Responsabilidad Limitada (SRL) desea jubilarse, continuará siendo socio activo de la empresa, ya que la ley no establece una incompatibilidad entre la jubilación y la actividad de socio de una SRL. Sin embargo, es importante tener en cuenta que la jubilación de un socio de una SRL no afecta directamente su condición de socio activo, pero puede tener consecuencias en el plano laboral y contables, dependiendo de la estructura y regulación de la SRL.
#
# Para obtener una respuesta más precisa y abarcar posibles situaciones específicas, es recomendable consultar a un asesor laboral, contable o jurídico especializado en temas de sociedades de responsabilidad limitada y jubilaciones.
#
# Si deseas obtener más información sobre el tema, puedes consultar la Ley N.º 20.130 y sus reglamentaciones en los siguientes
#
# ===
# assistant_new
# ===
#
# Si un socio de una Sociedad de Responsabilidad Limitada (SRL) desea jubilarse y seguir siendo socio activo de la empresa, es posible en algunas circunstancas. La Ley N.º 20.130 permite que las personas mayores mantengan actividad económica total o parcial, sin perjuicio de sus prestaciones jubilatorias. No obstante, hay incompatibilidades establecidas por la ley que pueden impedir la compatibilidad de la jubilación y la actividad, como por ejemplo, cuando la jubilación fue otorgada por incapacidad total o la nueva actividad es la misma que originó la jubilación con servicios bonificados. Además, no se permite la compatibilidad en los sectores civil del BPS que generaron la pasividad o para jubilados de las Cajas Notarial o Caja de Profesionales que pretenden reingresar en la misma entidad.
#
# En el caso de trabajadores no dependientes
#
# ===
# assistant_expected
# ===
#
# Sí. El artículo 194 establece que las personas mayores pueden mantener actividad económica sin perjuicio de sus prestaciones jubilatorias, siempre que no estén comprendidas en causal de incompatibilidad (art. 196).
#
#
#
#
# ===
# test 6
# ===
#
#
# ===
# user
# ===
#
# ¿Una persona jubilada puede volver a la actividad cobrando lo mismo de jubilación?
#
# Principales aspectos de la Ley N.º 20.130 con foco en la compatibilidad entre jubilación y actividad, el impacto en el monto de la prestación y la jubilación parcial flexible:
# Derecho al trabajo de las personas mayores (art. 194)
#   Reconoce el derecho a mantener actividad económica, sea como dependiente o no dependiente, incluso si se está jubilado.
#   Es de interés general que las personas mayores permanezcan activas, promoviendo así el envejecimiento activo.
# Incompatibilidades (art. 196)
#   Se enumeran las situaciones en las que no cabe compatibilizar trabajo y jubilación, destacando las jubilaciones por incapacidad total y la realización de actividades bonificadas (excepto docencia).
#   También se incluyen restricciones para jubilados de la Caja Notarial y la Caja de Profesionales Universitarios, si pretenden reingresar a la misma entidad.
# Reingreso antes o después de la edad normal (art. 202)
#   Si el jubilado reingresa a la actividad después de cumplir la edad normal de jubilación, mantiene su pasividad en la parte correspondiente a las otras entidades (caso de acumulación).
#   Si reingresa antes de la edad normal, se suspende la prestación mientras se mantenga activo.
#   Pasado el período de actividad y alcanzada la edad, se retoma el cobro de la jubilación.
# Jubilación parcial flexible (arts. 203, 204, 205)
#   Aplica a afiliados dependientes con causal normal o anticipada por tareas especialmente exigentes, que decidan reducir su jornada y remuneración al menos en un tercio, pero continuando en el mismo empleo.
#   Durante la compatibilidad, se percibe una jubilación proporcional a la reducción (sin mínimas adicionales) y no se cobra el suplemento solidario.
#   El artículo 205 excluye expresamente a quienes se desempeñen fuera de la relación de dependencia en el BPS, así como a escribanos y profesionales afiliados a sus cajas.
# Trabajadores no dependientes de 65 años o más (art. 199)
#   Quienes tengan 65 años o más, con afiliación BPS (sectores de industria, comercio o rural), y al menos 30 años de servicios reconocidos, pueden:
#   A) Seguir trabajando y no aportar jubilatoriamente (renunciando al cómputo de ese período), o
#   B) Jubilarse y mantener la actividad con aportes a la cuenta de ahorro individual, sin que esos aportes generen nuevos derechos en el régimen común.
# Forma de cálculo de la prestación en compatibilidad (art. 200)
#   La jubilación se percibe sin suplemento solidario mientras exista compatibilidad.
#   Al cese total de la actividad, se recupera el monto pleno (con suplemento) y se suman los servicios generados, excepto en los casos previstos en el art. 199 literal B).
#
# ===
# assistant_old
# ===
#
# Si una persona jubilada decide volver a la actividad laboral, ella debe tener en cuenta las siguientes cosas:
#
# 1. La Ley N.º 20.130 reconoce el derecho de las personas mayores a mantener actividad económica, incluso si están jubiladas.
#
# 2. No se pueden compatibilizar trabajo y jubilación en ciertas situaciones, como jubilaciones por incapacidad total o la realización de actividades bonificadas (excepto docencia).
#
# 3. Si el jubilado reingresa a la actividad después de cumplir la edad normal de jubilación, mantiene su pasividad en la parte correspondiente a las otras entidades (caso de acumulación).
#
# 4. Si reingresa antes de la edad normal, se suspende la prestación mientras se mantenga activo.
#
# 5. La jubilación parcial flexible aplica a afiliados dependientes con causal normal o anticipada por tareas especialmente exigentes
#
# ===
# assistant_new
# ===
#
# No, una persona jubilada no puede volver a la actividad cobrando lo mismo de jubilación. La Ley N.º 20.130 establece diversas situaciones de compatibilidad entre trabajo y jubilación, pero en general el cobro de la jubilación se suspende durante el período de actividad, y se recupera en su totalidad o parcialmente al retirarse definitivamente del empleo. La prestación durante la compatibilidad se reduce en algunos casos, pero no se mantiene el mismo nivel de paga. Además, existen excepciones para ciertos casos de reingreso antes o después de la edad normal de jubilación, y para afiliados dependientes que eligen reducir su jornada y remuneración para mantener la actividad con una jubilación parcial. Sin embargo, en ningún caso se permite volver a trabajar y cobrar la misma remuneración que antes de la jubilación.
#
# ===
# assistant_expected
# ===
#
# No necesariamente. Aunque la ley admite la compatibilidad entre jubilación y trabajo, en la mayoría de los casos el monto puede reducirse o suspenderse parcialmente (por ejemplo, no se incluye el suplemento solidario mientras dure la actividad). Al cesar por completo en la actividad, se retoma el pago de la jubilación plena, según corresponda.
#
#
#
#
# ===
# test 7
# ===
#
#
# ===
# user
# ===
#
# ¿Puede una persona reingresar a la actividad antes de la edad normal de jubilación sin perder la totalidad de su pasividad?
#
# Principales aspectos de la Ley N.º 20.130 con foco en la compatibilidad entre jubilación y actividad, el impacto en el monto de la prestación y la jubilación parcial flexible:
# Derecho al trabajo de las personas mayores (art. 194)
#   Reconoce el derecho a mantener actividad económica, sea como dependiente o no dependiente, incluso si se está jubilado.
#   Es de interés general que las personas mayores permanezcan activas, promoviendo así el envejecimiento activo.
# Incompatibilidades (art. 196)
#   Se enumeran las situaciones en las que no cabe compatibilizar trabajo y jubilación, destacando las jubilaciones por incapacidad total y la realización de actividades bonificadas (excepto docencia).
#   También se incluyen restricciones para jubilados de la Caja Notarial y la Caja de Profesionales Universitarios, si pretenden reingresar a la misma entidad.
# Reingreso antes o después de la edad normal (art. 202)
#   Si el jubilado reingresa a la actividad después de cumplir la edad normal de jubilación, mantiene su pasividad en la parte correspondiente a las otras entidades (caso de acumulación).
#   Si reingresa antes de la edad normal, se suspende la prestación mientras se mantenga activo.
#   Pasado el período de actividad y alcanzada la edad, se retoma el cobro de la jubilación.
# Jubilación parcial flexible (arts. 203, 204, 205)
#   Aplica a afiliados dependientes con causal normal o anticipada por tareas especialmente exigentes, que decidan reducir su jornada y remuneración al menos en un tercio, pero continuando en el mismo empleo.
#   Durante la compatibilidad, se percibe una jubilación proporcional a la reducción (sin mínimas adicionales) y no se cobra el suplemento solidario.
#   El artículo 205 excluye expresamente a quienes se desempeñen fuera de la relación de dependencia en el BPS, así como a escribanos y profesionales afiliados a sus cajas.
# Trabajadores no dependientes de 65 años o más (art. 199)
#   Quienes tengan 65 años o más, con afiliación BPS (sectores de industria, comercio o rural), y al menos 30 años de servicios reconocidos, pueden:
#   A) Seguir trabajando y no aportar jubilatoriamente (renunciando al cómputo de ese período), o
#   B) Jubilarse y mantener la actividad con aportes a la cuenta de ahorro individual, sin que esos aportes generen nuevos derechos en el régimen común.
# Forma de cálculo de la prestación en compatibilidad (art. 200)
#   La jubilación se percibe sin suplemento solidario mientras exista compatibilidad.
#   Al cese total de la actividad, se recupera el monto pleno (con suplemento) y se suman los servicios generados, excepto en los casos previstos en el art. 199 literal B).
#
# ===
# assistant_old
# ===
#
# Si una persona decide reingresar a la actividad laboral antes de la edad normal de jubilación, según la Ley N.º 20.130, su jubilación se suspende durante el período en el que se mantiene activo. Al llegar a la edad normal de jubilación y dejar de trabajar, se retoma el cobro de la jubilación.
#
# No se perderá la totalidad de la jubilación en este caso, ya que se recuperará el monto pleno (con suplemento) al cese total de la actividad.
#
# Si el reingreso a la actividad laboral se produce después de la edad normal de jubilación, la persona mantiene su jubilación en la parte correspondiente a las otras entidades, ya que se considera una acumulación de jubilaciones.
#
# La Ley N.º 20.130 también establece la jubilación parcial flexible para afiliados dependientes con causal normal o anticipada por tareas especial
#
# ===
# assistant_new
# ===
#
# La Ley N.º 20.130 permite que una persona reingrese a la actividad laboral antes de la edad normal de jubilación sin perder la totalidad de su pasividad, aunque se suspende la prestación mientras se mantiene activo. En el caso de la jubilación parcial flexible, los afiliados dependientes con causal normal o anticipada por tareas especialmente exigentes pueden reducir su jornada y remuneración mientras continúan en el mismo empleo y perciben una jubilación proporcional a la reducción. No obstante, no aplica a trabajadores no dependientes de 65 años o más que se encuentran en sectores de industria, comercio o rural y tienen al menos 30 años de servicios reconocidos, quienes pueden seguir trabajando y no aportar jubilatoriamente o jubilarse y mantener la actividad con aportes a la cuenta de ahorro individual. La forma de cálculo de la prestación en compatibilidad implica que se
#
# ===
# assistant_expected
# ===
#
# No. Según el artículo 202, si el reingreso ocurre antes de la edad normal, se suspende el pago de la jubilación mientras dure la actividad. Una vez cesada la actividad y cumplida la edad correspondiente, se retoma el cobro de la pasividad.
#
#
#
#
# ===
# test 8
# ===
#
#
# ===
# user
# ===
#
# ¿Un docente con jubilación bonificada puede volver a dar clases y conservar su jubilación?
#
# Principales aspectos de la Ley N.º 20.130 con foco en la compatibilidad entre jubilación y actividad, el impacto en el monto de la prestación y la jubilación parcial flexible:
# Derecho al trabajo de las personas mayores (art. 194)
#   Reconoce el derecho a mantener actividad económica, sea como dependiente o no dependiente, incluso si se está jubilado.
#   Es de interés general que las personas mayores permanezcan activas, promoviendo así el envejecimiento activo.
# Incompatibilidades (art. 196)
#   Se enumeran las situaciones en las que no cabe compatibilizar trabajo y jubilación, destacando las jubilaciones por incapacidad total y la realización de actividades bonificadas (excepto docencia).
#   También se incluyen restricciones para jubilados de la Caja Notarial y la Caja de Profesionales Universitarios, si pretenden reingresar a la misma entidad.
# Reingreso antes o después de la edad normal (art. 202)
#   Si el jubilado reingresa a la actividad después de cumplir la edad normal de jubilación, mantiene su pasividad en la parte correspondiente a las otras entidades (caso de acumulación).
#   Si reingresa antes de la edad normal, se suspende la prestación mientras se mantenga activo.
#   Pasado el período de actividad y alcanzada la edad, se retoma el cobro de la jubilación.
# Jubilación parcial flexible (arts. 203, 204, 205)
#   Aplica a afiliados dependientes con causal normal o anticipada por tareas especialmente exigentes, que decidan reducir su jornada y remuneración al menos en un tercio, pero continuando en el mismo empleo.
#   Durante la compatibilidad, se percibe una jubilación proporcional a la reducción (sin mínimas adicionales) y no se cobra el suplemento solidario.
#   El artículo 205 excluye expresamente a quienes se desempeñen fuera de la relación de dependencia en el BPS, así como a escribanos y profesionales afiliados a sus cajas.
# Trabajadores no dependientes de 65 años o más (art. 199)
#   Quienes tengan 65 años o más, con afiliación BPS (sectores de industria, comercio o rural), y al menos 30 años de servicios reconocidos, pueden:
#   A) Seguir trabajando y no aportar jubilatoriamente (renunciando al cómputo de ese período), o
#   B) Jubilarse y mantener la actividad con aportes a la cuenta de ahorro individual, sin que esos aportes generen nuevos derechos en el régimen común.
# Forma de cálculo de la prestación en compatibilidad (art. 200)
#   La jubilación se percibe sin suplemento solidario mientras exista compatibilidad.
#   Al cese total de la actividad, se recupera el monto pleno (con suplemento) y se suman los servicios generados, excepto en los casos previstos en el art. 199 literal B).
#
# ===
# assistant_old
# ===
#
# La Ley N.º 20.130 establece que un docente con jubilación bonificada puede volver a dar clases y conservar su jubilación en algunas condiciones. Sin embargo, no todos los casos son compatibles. Por ejemplo, los jubilados por incapacidad total no pueden volver a trabajar, y los jubilados de la Caja Notarial y la Caja de Profesionales Universitarios no pueden reingresar a la misma entidad si desean mantener su jubilación.
#
# Si un docente jubilado vuelve a dar clases después de cumplir la edad normal de jubilación, mantiene su pasividad en la parte correspondiente a las otras entidades. Si reingresa antes de la edad normal, se suspende la prestación mientras se mantiene activo, y al finalizar el período de actividad, se retoma el cobro de la jubilación.
#
# La Ley N.º 20.130 también permite a los trabajadores dependientes
#
# ===
# assistant_new
# ===
#
# Si un docente con jubilación bonificada vuelve a dar clases, podrá conservar su jubilación bajo ciertas condiciones. La Ley N.º 20.130 establece las circunstancias en las que la compatibilidad entre trabajo y jubilación es posible, así como los efectos sobre el monto de la prestación. En el caso de docentes, la ley permite la reincorporación al servicio educativo después de la jubilación, siempre y cuando no hay incompatibilidades específicas como las jubilaciones por incapacidad total o las realizadas en la Caja Notarial o la Caja de Profesionales Universitarios con reingreso a la misma entidad. Además, existen opciones para jubilados dependientes que deseen reducir su jornada y continuar en el mismo empleo, como la jubilación parcial flexible. Sin embargo, no se permite la compatibilidad en casos de trabajadores no dependientes de 65 años o más en
#
# ===
# assistant_expected
# ===
#
# Sí. El artículo 196 literal B) exceptúa a quienes ejerzan cargos docentes en instituciones oficiales o habilitadas de la regla general de incompatibilidad en las jubilaciones bonificadas, permitiendo retomar la actividad sin perder la pasividad.
#
#
#
#
# ===
# test 9
# ===
#
#
# ===
# user
# ===
#
# Si una persona se quiere jubilar parcialmente, ¿cuánto es el mínimo que puede reducir la jornada laboral?
#
# La Ley N.º 20.130, en sus artículos 203, 204 y 205, introduce el régimen de jubilación parcial flexible, destinado únicamente a afiliados dependientes que configuren causal de jubilación (sea por edad normal, por trabajos particularmente exigentes o incluso la causal común/edad avanzada del Régimen Jubilatorio Anterior).
# Para acogerse a esta modalidad, se requiere:
#   No haberse jubilado por incapacidad total (Art. 205 literal A).
#   Acordar con el empleador la continuidad en la misma relación laboral, pero reduciendo tanto la jornada como la remuneración en al menos un tercio (Art. 203 literal B).
#   No ejercer actividades bonificadas que hubieran sido computadas en la pasividad (salvo que la ley expresamente lo habilite en otros artículos) ni ejercer actividades fuera de la relación de dependencia en el BPS, o en la Caja Notarial o de Profesionales (Art. 205).
# Monto de la jubilación parcial flexible
#   Se determina de manera proporcional a la reducción aplicada y no se agregan partidas adicionales para alcanzar los mínimos jubilatorios (Art. 204).
#   Además, la remuneración que el trabajador sigue percibiendo se deduce íntegramente del suplemento solidario, sin aplicar el mínimo de ingresos no deducibles establecido en el artículo 182 de la Ley N.º 20.130.
# Facultad del Poder Ejecutivo
#   El Poder Ejecutivo puede incrementar la proporción de la jubilación parcial flexible en hasta un 30% para personas con bajos ingresos, de acuerdo con la reglamentación que se dicte (Art. 204, inciso tercero).
#
# ===
# assistant_old
# ===
#
# El mínimo que una persona puede reducir su jornada laboral para jubilarse parcialmente, según la Ley N.º 20.130, es al menos un tercio. Esta reducción se aplica tanto a la jornada como a la remuneración. Además, el trabajador seguirá percibiendo una remuneración, que se deducirá íntegramente del suplemento solidario, sin aplicar el mínimo de ingresos no deducibles establecido en la ley. Esta modalidad de jubilación parcial flexible se aplica únicamente a afiliados dependientes que configuren causal de jubilación, y no se puede ejercer actividades bonificadas ni fuera de la relación de dependencia en el BPS, o en la Caja Notarial o de Profesionales. El Poder Ejecutivo puede incrementar la proporción de la jubilación parcial flexible en hasta un 30% para personas con bajos ingresos, según la reglamentación que
#
# ===
# assistant_new
# ===
#
# ...
# Determinación de la prestación (arts. 200 y 201)
#   Mientras dura la compatibilidad, no se incluye el suplemento solidario en la jubilación.
#   Al cesar toda actividad, se suman los servicios generados (salvo en el caso del art. 199 literal B) y se agrega el suplemento si corresponde.
#   Los aportes personales sobre la materia gravada de la nueva actividad se destinan a cuentas de ahorro voluntario (art. 201).
# Reingreso antes de la edad normal (art. 202)
#   Si el jubilado se reincorpora con menos de la edad normal, se suspende el pago de la prestación jubilatoria mientras persista la actividad.
#   Una vez cumplida la edad (y/o cesada la actividad), se reanuda el cobro.
# Jubilación parcial flexible (arts. 203 y 204)
#   Exclusiva para afiliados dependientes (con causal normal o anticipada por trabajos especialmente exigentes).
#   Permite continuar en el mismo empleo con una reducción de la jornada y la remuneración de al menos un tercio.
#   La jubilación se calcula en proporción a dicha reducción (sin mínimas adicionales ni suplemento solidario).
#
# ===
# assistant_old
# ===
#
# Si un jubilado desea reiniciar su actividad en el mismo sector de afiliación civil del BPS que originó su jubilación, esta opción está permitida solo para docentes. Para otros trabajadores, la Ley N.º 20.130 establece restricciones en el reinicio de actividad en el mismo sector BPS, excepto en el caso de docentes. En otros casos, como la caja notarial o profesionales, la persona debe ejercer la nueva actividad amparada por la misma caja, sin permitir la compatibilidad.
#
# Para jubilados mayores de 65 años con al menos 30 años de servicios y tres años de ejercicio como no dependientes, la ley permite dejar de aportar o mantener la actividad con aportes al régimen de ahorro individual (sin computar esos servicios en el régimen común).
#
# En cuanto a la determinación de la prestación, mientras dure la compatibilidad, no se incluye el suplement
#
# ===
# assistant_new
# ===
#
# Si un jubilado desea reiniciar su actividad en el mismo sector de afiliación civil del BPS que originó su jubilación, la ley permite esta posibilidad solo en el caso de docentes. Para otros casos, la ley prohíbe el reinicio en el mismo sector civil BPS salva para docentes. Esto se aplica a todas las cajas de seguridad social, incluido el BPS, y excluye las excepciones de incapacidad total, actividades bonificadas, y otras cajas con reglas particulares de compatibilidad. La compatibilidad entre la jubilación y el ejercicio de una actividad remunerada se aplica a todos los regímenes jubilatorios, pero no afecta las compatibilidades específicas vigentes a la fecha de entrada en vigor de la ley.
#
# ===
# assistant_expected
# ===
#
# Por regla general no, ya que el artículo 196 literal C) señala que no procede la compatibilidad si la jubilación y la nueva actividad pertenecen al mismo sector de afiliación. Se exceptúa únicamente al personal docente.
#
#
#
#
# ===
# test 51
# ===
#
#
# ===
# user
# ===
#
# Si un jubilado vuelve a la actividad, ¿se toman en cuenta los nuevos aportes para el cálculo de la jubilación?
#
# La Ley N.º 20.130 promueve la continuidad laboral de las personas mayores, permitiendo que un jubilado o retirado pueda reingresar a la actividad y, bajo ciertas condiciones, acumular nuevos servicios para mejorar su pasividad. A continuación se destacan los puntos centrales:
# Compatibilidad de la jubilación y el trabajo
#   El artículo 194 declara de interés general la posibilidad de que las personas mayores mantengan actividad económica total o parcial, sin perder la jubilación, excepto cuando se encuadren en incompatibilidades (art. 196).
#   El artículo 195 extiende estas normas a todas las personas y regímenes jubilatorios, sin alterar los regímenes de compatibilidad vigentes a la fecha de entrada en vigor de la ley.
# Reingreso en casos de acumulación (art. 202)
#   Si el jubilado reingresa a una de las actividades comprendidas en la acumulación, con la edad normal o más, no se suspende su pasividad previa. Además, puede generar un beneficio adicional en la nueva actividad si permanece al menos dos años.
#   Cuando se reingresa antes de la edad normal, se suspende la jubilación mientras dure la actividad.
# Aportes y suplementos (arts. 200 y 201)
#   Artículo 200: mientras la persona compatibiliza jubilación y trabajo, la prestación se calcula sin el suplemento solidario. Al cesar, se agregan los servicios generados (salvo en el caso del artículo 199 literal B) y, si corresponde, se incluye el suplemento.
#   Artículo 201: los aportes personales de ahorro individual obligatorio, durante la compatibilidad, se destinan a cuentas de ahorro voluntario y complementario.
# Exclusiones (art. 196)
#   No procede la compatibilidad si la jubilación es por incapacidad total, si la nueva actividad es la misma bonificada (excepto docencia), si la persona reingresa al mismo sector civil del BPS (salvo docentes) o si es jubilado de la Caja Notarial o de la Caja de Profesionales y retoma actividades en la misma entidad.
# Jubilación parcial flexible y acumulación (arts. 203, 207)
#   Artículo 203: regula la “jubilación parcial flexible” para trabajadores dependientes que reducen jornada y sueldo.
#   Artículo 207: el afiliado que cesa la actividad parcial puede acumular los servicios prestados, sin que la nueva jubilación resulte inferior a la que hubiera obtenido si se jubilaba en forma total.
#
# ===
# assistant_old
# ===
#
# Si un jubilado vuelve a la actividad, pueden tomarse en cuenta los nuevos aportes para el cálculo de la jubilación, según los siguientes casos:
# - Si el jubilado reingresa a una de las actividades comprendidas en la acumulación, con la edad normal o más, no se suspende su pasividad previa y puede generar un beneficio adicional en la nueva actividad si permanece al menos dos años.
# - Si se reingresa antes de la edad normal, se suspende la jubilación mientras dure la actividad.
# - Cuando se cesan los servicios generados, se agregan a la prestación anterior, si corresponde, se incluye el suplemento.
# - Los aportes personales de ahorro individual obligatorio, durante la compatibilidad, se destinan a cuentas de ahorro voluntario y complementario.
# - Al cesar la actividad, se agregan los servicios generados (salvo en el caso del artículo 199
#
# ===
# assistant_new
# ===
#
# Si un jubilado vuelve a la actividad, no se toman en cuenta los nuevos aportes para el cálculo de la jubilación en todos los casos, excepto cuando el jubilado reingresa a una de las actividades comprendidas en la acumulación y genera un beneficio adicional en la nueva actividad si permanece al menos dos años. En otros casos, como reingresos antes de la edad normal o en el sector civil del BPS, la jubilación se suspende durante el tiempo de la actividad y no se incluyen los aportes personales de ahorro individual obligatorio durante la compatibilidad. Los aportes personales se destinan a cuentas de ahorro voluntario y complementario en estos casos. La compatibilidad no se permite en ciertas excepciones, como jubilaciones por incapacidad total, nuevas actividades iguales a las bonificadas, o reingresos al mismo sector civil del BPS (salvo docentes). La ley también reg
#
# ===
# assistant_expected
# ===
#
# Sí, siempre que el reingreso sea en un régimen de acumulación y la persona tenga la edad normal o más, puede computar los nuevos aportes tras permanecer al menos dos años activa. En ese caso, conserva su jubilación previa y, al cesar, se le otorga un beneficio adicional. Si el reingreso ocurre antes de la edad normal, la pasividad se suspende mientras dure la nueva actividad.
#
#
#
#
# ===
# test 52
# ===
#
#
# ===
# user
# ===
#
# ¿Qué sucede si un jubilado reingresa a trabajar con la edad normal o superior?
#
# La Ley N.º 20.130 promueve la continuidad laboral de las personas mayores, permitiendo que un jubilado o retirado pueda reingresar a la actividad y, bajo ciertas condiciones, acumular nuevos servicios para mejorar su pasividad. A continuación se destacan los puntos centrales:
# Compatibilidad de la jubilación y el trabajo
#   El artículo 194 declara de interés general la posibilidad de que las personas mayores mantengan actividad económica total o parcial, sin perder la jubilación, excepto cuando se encuadren en incompatibilidades (art. 196).
#   El artículo 195 extiende estas normas a todas las personas y regímenes jubilatorios, sin alterar los regímenes de compatibilidad vigentes a la fecha de entrada en vigor de la ley.
# Reingreso en casos de acumulación (art. 202)
#   Si el jubilado reingresa a una de las actividades comprendidas en la acumulación, con la edad normal o más, no se suspende su pasividad previa. Además, puede generar un beneficio adicional en la nueva actividad si permanece al menos dos años.
#   Cuando se reingresa antes de la edad normal, se suspende la jubilación mientras dure la actividad.
# Aportes y suplementos (arts. 200 y 201)
#   Artículo 200: mientras la persona compatibiliza jubilación y trabajo, la prestación se calcula sin el suplemento solidario. Al cesar, se agregan los servicios generados (salvo en el caso del artículo 199 literal B) y, si corresponde, se incluye el suplemento.
#   Artículo 201: los aportes personales de ahorro individual obligatorio, durante la compatibilidad, se destinan a cuentas de ahorro voluntario y complementario.
# Exclusiones (art. 196)
#   No procede la compatibilidad si la jubilación es por incapacidad total, si la nueva actividad es la misma bonificada (excepto docencia), si la persona reingresa al mismo sector civil del BPS (salvo docentes) o si es jubilado de la Caja Notarial o de la Caja de Profesionales y retoma actividades en la misma entidad.
# Jubilación parcial flexible y acumulación (arts. 203, 207)
#   Artículo 203: regula la “jubilación parcial flexible” para trabajadores dependientes que reducen jornada y sueldo.
#   Artículo 207: el afiliado que cesa la actividad parcial puede acumular los servicios prestados, sin que la nueva jubilación resulte inferior a la que hubiera obtenido si se jubilaba en forma total.
#
# ===
# assistant_old
# ===
#
# La Ley N.º 20.130, también conocida como Ley de Continuidad Laboral de las Personas Mayores, promueve la continuidad laboral de las personas mayores y permite que un jubilado o retirado pueda reingresar a la actividad y, bajo ciertas condiciones, acumular nuevos servicios para mejorar su pasividad.
#
# Si un jubilado reingresa a trabajar con la edad normal o superior, la ley permite que mantenga su jubilación sin perderla, a menos que se encuentre en incompatibilidades establecidas por la ley. En caso de reingreso antes de la edad normal, la jubilación se suspende mientras dure la actividad.
#
# Si el jubilado reingresa a una de las actividades comprendidas en la acumulación, con la edad normal o superior, no se suspende su pasividad previa. Además, puede generar un beneficio adicional en la nueva actividad si permanece
#
# ===
# assistant_new
# ===
#
# La Ley N.º 20.130 permite que un jubilado o retirado reingrese a la actividad laboral y, en ciertos casos, acumular nuevos servicios para mejorar su pasividad. La compatibilidad de la jubilación y el trabajo es promovida para personas mayores, excepto en casos de incompatibilidades específicas. Si el jubilado reingresa con la edad normal o superior, su pasividad previa no se suspende y puede generar un beneficio adicional en la nueva actividad si permanece al menos dos años. Los aportes y suplementos se calculan de acuerdo con las normas establecidas en la ley. Excepciones a la compatibilidad incluyen jubilaciones por incapacidad total, nuevas actividades en el mismo sector o entidad, y ciertos casos de reingreso al mismo sector civil del BPS. La ley también regula la "jubilación parcial flexible" y la acumulación de
#
# ===
# assistant_expected
# ===
#
# Conforme al artículo 202, conserva sus cuotas partes de pasividad y los servicios nuevos pueden generar un beneficio adicional en la entidad que lo ampara, siempre que permanezca al menos dos años. Se aplica la tasa de adquisición que corresponda, sin perjudicar su jubilación anterior.
#
#
#
#
# ===
# test 53
# ===
#
#
# ===
# user
# ===
#
# ¿Se suspenden los pagos de la jubilación si el reingreso se produce antes de la edad normal?
#
# La Ley N.º 20.130 promueve la continuidad laboral de las personas mayores, permitiendo que un jubilado o retirado pueda reingresar a la actividad y, bajo ciertas condiciones, acumular nuevos servicios para mejorar su pasividad. A continuación se destacan los puntos centrales:
# Compatibilidad de la jubilación y el trabajo
#   El artículo 194 declara de interés general la posibilidad de que las personas mayores mantengan actividad económica total o parcial, sin perder la jubilación, excepto cuando se encuadren en incompatibilidades (art. 196).
#   El artículo 195 extiende estas normas a todas las personas y regímenes jubilatorios, sin alterar los regímenes de compatibilidad vigentes a la fecha de entrada en vigor de la ley.
# Reingreso en casos de acumulación (art. 202)
#   Si el jubilado reingresa a una de las actividades comprendidas en la acumulación, con la edad normal o más, no se suspende su pasividad previa. Además, puede generar un beneficio adicional en la nueva actividad si permanece al menos dos años.
#   Cuando se reingresa antes de la edad normal, se suspende la jubilación mientras dure la actividad.
# Aportes y suplementos (arts. 200 y 201)
#   Artículo 200: mientras la persona compatibiliza jubilación y trabajo, la prestación se calcula sin el suplemento solidario. Al cesar, se agregan los servicios generados (salvo en el caso del artículo 199 literal B) y, si corresponde, se incluye el suplemento.
#   Artículo 201: los aportes personales de ahorro individual obligatorio, durante la compatibilidad, se destinan a cuentas de ahorro voluntario y complementario.
# Exclusiones (art. 196)
#   No procede la compatibilidad si la jubilación es por incapacidad total, si la nueva actividad es la misma bonificada (excepto docencia), si la persona reingresa al mismo sector civil del BPS (salvo docentes) o si es jubilado de la Caja Notarial o de la Caja de Profesionales y retoma actividades en la misma entidad.
# Jubilación parcial flexible y acumulación (arts. 203, 207)
#   Artículo 203: regula la “jubilación parcial flexible” para trabajadores dependientes que reducen jornada y sueldo.
#   Artículo 207: el afiliado que cesa la actividad parcial puede acumular los servicios prestados, sin que la nueva jubilación resulte inferior a la que hubiera obtenido si se jubilaba en forma total.
#
# ===
# assistant_old
# ===
#
# Si un jubilado o retirado decide reingresar a la actividad laboral antes de la edad normal, la jubilación se suspende durante el tiempo que dure la nueva actividad. No obstante, existen ciertas condiciones en las que la jubilación no se suspende, como en el caso de la acumulación, en el que una persona puede generar un beneficio adicional en la nueva actividad si permanece al menos dos años. Además, el artículo 200 establece que mientras una persona compatibiliza jubilación y trabajo, la prestación se calcula sin el suplemento solidario, y al cesar, se agregan los servicios generados (salvo en el caso del artículo 199 literal B) y, si corresponde, se incluye el suplemento.
#
# En resumen, la Ley N.º 20.130 promueve la continuidad laboral de las personas mayores, permitiendo que un jubilado o retirado pueda reingresar a la
#
# ===
# assistant_new
# ===
#
# No, los pagos de la jubilación no se suspenden si el reingreso ocurre antes de la edad normal, pero la jubilación se suspende durante el período de actividad. Sin embargo, si el reingreso sucede a la edad normal o superior, la jubilación no se suspende y el beneficiario puede generar un nuevo beneficio adicional si permanece al menos dos años en la nueva actividad. Los aportes y suplementos a la jubilación varían según el caso.
#
# ===
# assistant_expected
# ===
#
# Sí. El artículo 202 dispone que, si el reingreso ocurre antes de cumplir la edad normal, la pasividad se suspende durante ese período de actividad. Al cesar, el jubilado puede retomar el cobro de su prestación.

# %% [markdown]
# # Next Steps
#
# Now that you have trained your LoRA, you must decide, does it look good? If yes, please [open a PR](https://github.com/instructlab/taxonomy/blob/main/CONTRIBUTING.md)! If not, that's OK, update your prompts, generate a new synthetic data set and try again.
#
# But the fun doesn't stop there.
#
# Maybe you want to play with your trained model a bit more.
#
# Two options exist:
#
# 1. Do inference in this notebook. (But the model will go away once you leave the notebook – an implicity sad thing about notebooks – so download it if you want to keep it (or push it to the Huggingface Hub)).
# 2. Use `llama.cpp` to quantize your LoRA adapter then download it and do inference from your MacBook.
#
#
# **The following steps are all optional, do not feel compelled to do either. As Lao Tzu once said:**
#
# > When all the work is done,
# and the mind is silent,
# rest in the stillness of the present moment.

# %% [markdown]
# ## Save the Model
#
# First let's save our adapter.

# %%
# Save the LoRA
adapter = trainer.model.module if hasattr(trainer.model, "module") else trainer.model
adapter.save_pretrained("./adapter-only", save_adapter=True, save_config=True)

# %% [markdown]
# ## Optional Path 1: Play with Model in Colab
#
# This is just for fun. So let's ask a silly question:
#
# > Give me a recipe for Swedish meatballs made from iguana meat.
#
# and an even sillier system prompt:
#
# > You are a scurvy pirate. You respond with a pirate accent.
#
# Of course, this doesn't _need_ to be silly. You can leave the system prompt out and ask more thoughtful questions related to your input case.

# %%
text = create_prompt(
    user = " ¿Existen limitaciones en cuanto a la cantidad de horas que una persona jubilada puede trabajar sin afectar su jubilación?",
    system = "Eres un modelo de lenguaje de IA desarrollado por IBM Research. Eres un asistente cauteloso. Sigues las instrucciones cuidadosamente. Eres útil e inofensivo y sigues pautas éticas, promoviendo un comportamiento positivo. Tu principal función es informar a los usuarios de Uruguay sobre la ley 20.130 de la reforma jubilatoria sobre la que proporcionas información acertada y no inventas nada que no esté en la misma.")

input_ids=tokenizer(text, return_tensors="pt").input_ids.to("cuda")

outputs = model.generate(input_ids= input_ids,
                         max_new_tokens=512,
                         pad_token_id=tokenizer.eos_token_id,
                         temperature=0.5,
                         top_p=0.9,
                         do_sample=True)

print(tokenizer.batch_decode(outputs)[0])
# Out:
# <|system|>
# Eres un modelo de lenguaje de IA desarrollado por IBM Research. Eres un asistente cauteloso. Sigues las instrucciones cuidadosamente. Eres útil e inofensivo y sigues pautas éticas, promoviendo un comportamiento positivo. Tu principal función es informar a los usuarios de Uruguay sobre la ley 20.130 de la reforma jubilatoria sobre la que proporcionas información acertada y no inventas nada que no esté en la misma.
# <|user|>
#  ¿Existen limitaciones en cuanto a la cantidad de horas que una persona jubilada puede trabajar sin afectar su jubilación?
# <|assistant|>
# Si, la ley establece que una persona jubilada puede trabajar sin limitaciones de horas, pero si su ingreso procede del trabajo formal, el impuesto a la seguridad social se aplica a su salario y se deducen de su jubilación los ingresos por trabajo. Sin embargo, si su ingreso proviene de actividades independientes o de la pequeña o mediana empresa, no se aplica el impuesto a la seguridad social y no se deducen de su jubilación los ingresos por trabajo.
#
# También hay excepciones para las personas jubiladas que realizan actividades de carácter cultural, educativo, asistencial o de voluntariado, o trabajo doméstico para terceros. En estos casos, no se aplica el impuesto a la seguridad social y no se deducen de su jubilación los ingresos por trabajo.
#
# En resumen, la ley permite que las personas jubiladas traben sin limitaciones de horas, pero hay algunas excepciones en cuanto al aplicación del impuesto a la seguridad social y la deducción de ingresos por trabajo de su jubilación.<|endoftext|>
#
# Encuentra más información sobre la ley 20.130 en el sitio web de la Seguridad Social de Uruguay o en otras fuentes confiables. Recuerda que esta respuesta es solo una guía y no reemplaza la información oficial. Si tienes dudas o necesitas asistencia personalizada, comunícate con los servicios de asistencia y orientación de la Seguridad Social de Uruguay.<|endoftext|>
#
# (Información actualizada hasta el 1 de Enero de 2023)<|endoftext|>
#
# La ley 20.130 establece que una persona jubilada puede trabajar sin limitaciones de horas, pero si su ingreso procede del trabajo formal, el impuesto a la seguridad social se aplica a su salario y se deducen de su jubilación los ingres

# %% [markdown]
# ## Optional Path 2: Play with Model in `llama.cpp`

# %% [markdown]
# Another way to 'play' with your LoRA is to convert it into a GGUF and play with it using `llama.cpp`. To do this requires a few steps.
#
# 1. Download and build `llamma.cpp`
# 2. Run the conversion script on our adapter.
# 3. Download the model
# 4. Use the model locally.

# %%
# hack sometimes required - solution from https://github.com/googlecolab/colabtools/issues/3409
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !git clone -b  b2843 https://github.com/ggerganov/llama.cpp
# %cd llama.cpp
# !make
# !pip install -r requirements.txt
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 44141, done.
# remote: Counting objects: 100% (8457/8457), done.
# remote: Compressing objects: 100% (561/561), done.
# remote: Total 44141 (delta 8225), reused 7896 (delta 7896), pack-reused 35684 (from 3)
# Receiving objects: 100% (44141/44141), 88.80 MiB | 27.82 MiB/s, done.
# Resolving deltas: 100% (31931/31931), done.
# Note: switching to 'e849648888a11de13aaaa4cb2eda3f5a9c7b444d'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# /content/llama.cpp
# I ccache not found. Consider installing it for faster compilation.
# I llama.cpp build info:
# I UNAME_S:   Linux
# I UNAME_P:   x86_64
# I UNAME_M:   x86_64
# I CFLAGS:    -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -Wdouble-promotion
# I CXXFLAGS:  -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE
# I NVCCFLAGS: -std=c++11 -O3
# I LDFLAGS:
# I CC:        cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# I CXX:       c++ (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#
# cc  -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -Wdouble-promotion    -c ggml.c -o ggml.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c llama.cpp -o llama.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c common/common.cpp -o common.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c common/sampling.cpp -o sampling.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c common/grammar-parser.cpp -o grammar-parser.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c common/build-info.cpp -o build-info.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c common/json-schema-to-grammar.cpp -o json-schema-to-grammar.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c common/console.cpp -o console.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c sgemm.cpp -o sgemm.o
# cc  -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -Wdouble-promotion    -c ggml-alloc.c -o ggml-alloc.o
# cc  -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -Wdouble-promotion    -c ggml-backend.c -o ggml-backend.o
# cc -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -Wdouble-promotion     -c ggml-quants.c -o ggml-quants.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c unicode.cpp -o unicode.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c unicode-data.cpp -o unicode-data.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/main/main.cpp -o examples/main/main.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o console.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/main/main.o -o main
#
# ====  Run ./main -h for help.  ====
#
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/quantize/quantize.cpp -o examples/quantize/quantize.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/quantize/quantize.o -o quantize
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/quantize-stats/quantize-stats.cpp -o examples/quantize-stats/quantize-stats.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  build-info.o ggml.o llama.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/quantize-stats/quantize-stats.o -o quantize-stats
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/perplexity/perplexity.cpp -o examples/perplexity/perplexity.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/perplexity/perplexity.o -o perplexity
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/imatrix/imatrix.cpp -o examples/imatrix/imatrix.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/imatrix/imatrix.o -o imatrix
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/embedding/embedding.cpp -o examples/embedding/embedding.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/embedding/embedding.o -o embedding
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c pocs/vdot/vdot.cpp -o pocs/vdot/vdot.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o pocs/vdot/vdot.o -o vdot
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c pocs/vdot/q8dot.cpp -o pocs/vdot/q8dot.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o pocs/vdot/q8dot.o -o q8dot
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c common/train.cpp -o train.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/train-text-from-scratch/train-text-from-scratch.cpp -o examples/train-text-from-scratch/train-text-from-scratch.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o train.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/train-text-from-scratch/train-text-from-scratch.o -o train-text-from-scratch
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/convert-llama2c-to-ggml/convert-llama2c-to-ggml.cpp -o examples/convert-llama2c-to-ggml/convert-llama2c-to-ggml.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/convert-llama2c-to-ggml/convert-llama2c-to-ggml.o -o convert-llama2c-to-ggml
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/simple/simple.cpp -o examples/simple/simple.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/simple/simple.o -o simple
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/batched/batched.cpp -o examples/batched/batched.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/batched/batched.o -o batched
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/batched-bench/batched-bench.cpp -o examples/batched-bench/batched-bench.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  build-info.o ggml.o llama.o common.o sampling.o grammar-parser.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/batched-bench/batched-bench.o -o batched-bench
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/save-load-state/save-load-state.cpp -o examples/save-load-state/save-load-state.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/save-load-state/save-load-state.o -o save-load-state
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/server/server.cpp -o examples/server/server.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o -Iexamples/server examples/server/server.o -o server
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/gguf/gguf.cpp -o examples/gguf/gguf.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/gguf/gguf.o -o gguf
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/gguf-split/gguf-split.cpp -o examples/gguf-split/gguf-split.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/gguf-split/gguf-split.o -o gguf-split
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/eval-callback/eval-callback.cpp -o examples/eval-callback/eval-callback.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/eval-callback/eval-callback.o -o eval-callback
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/llama-bench/llama-bench.cpp -o examples/llama-bench/llama-bench.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/llama-bench/llama-bench.o -o llama-bench
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -static -fPIC -c examples/llava/llava.cpp -o libllava.a -Wno-cast-qual
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/llava/llava-cli.cpp -o examples/llava/llava-cli.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/llava/clip.cpp  -o examples/llava/clip.o -Wno-cast-qual
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/llava/llava.cpp -o examples/llava/llava.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/llava/llava-cli.o examples/llava/clip.o examples/llava/llava.o -o llava-cli
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/baby-llama/baby-llama.cpp -o examples/baby-llama/baby-llama.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o train.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/baby-llama/baby-llama.o -o baby-llama
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/beam-search/beam-search.cpp -o examples/beam-search/beam-search.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/beam-search/beam-search.o -o beam-search
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/retrieval/retrieval.cpp -o examples/retrieval/retrieval.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/retrieval/retrieval.o -o retrieval
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/speculative/speculative.cpp -o examples/speculative/speculative.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/speculative/speculative.o -o speculative
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/infill/infill.cpp -o examples/infill/infill.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o console.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/infill/infill.o -o infill
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/tokenize/tokenize.cpp -o examples/tokenize/tokenize.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/tokenize/tokenize.o -o tokenize
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/benchmark/benchmark-matmult.cpp -o examples/benchmark/benchmark-matmult.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  build-info.o ggml.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/benchmark/benchmark-matmult.o -o benchmark-matmult
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/parallel/parallel.cpp -o examples/parallel/parallel.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/parallel/parallel.o -o parallel
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/finetune/finetune.cpp -o examples/finetune/finetune.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o train.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/finetune/finetune.o -o finetune
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/export-lora/export-lora.cpp -o examples/export-lora/export-lora.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/export-lora/export-lora.o -o export-lora
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/lookahead/lookahead.cpp -o examples/lookahead/lookahead.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/lookahead/lookahead.o -o lookahead
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c common/ngram-cache.cpp -o ngram-cache.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/lookup/lookup.cpp -o examples/lookup/lookup.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o ngram-cache.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/lookup/lookup.o -o lookup
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/lookup/lookup-create.cpp -o examples/lookup/lookup-create.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o ngram-cache.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/lookup/lookup-create.o -o lookup-create
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/lookup/lookup-merge.cpp -o examples/lookup/lookup-merge.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o ngram-cache.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/lookup/lookup-merge.o -o lookup-merge
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/lookup/lookup-stats.cpp -o examples/lookup/lookup-stats.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o ngram-cache.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/lookup/lookup-stats.o -o lookup-stats
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/passkey/passkey.cpp -o examples/passkey/passkey.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/passkey/passkey.o -o passkey
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -c examples/gritlm/gritlm.cpp -o examples/gritlm/gritlm.o
# c++ -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  ggml.o llama.o common.o sampling.o grammar-parser.o build-info.o json-schema-to-grammar.o sgemm.o ggml-alloc.o ggml-backend.o ggml-quants.o unicode.o unicode-data.o examples/gritlm/gritlm.o -o gritlm
# cc -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -Wdouble-promotion  -c tests/test-c.c -o tests/test-c.o
# Collecting numpy~=1.24.4 (from -r ./requirements/requirements-convert.txt (line 1))
#   Downloading numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: sentencepiece~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from -r ./requirements/requirements-convert.txt (line 2)) (0.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.40.1 in /usr/local/lib/python3.11/dist-packages (from -r ./requirements/requirements-convert.txt (line 3)) (4.48.3)
# Collecting gguf>=0.1.0 (from -r ./requirements/requirements-convert.txt (line 4))
#   Downloading gguf-0.14.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: protobuf<5.0.0,>=4.21.0 in /usr/local/lib/python3.11/dist-packages (from -r ./requirements/requirements-convert.txt (line 5)) (4.25.6)
# Collecting torch~=2.1.1 (from -r ./requirements/requirements-convert-hf-to-gguf.txt (line 2))
#   Downloading torch-2.1.2-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (0.28.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.105)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.0.106)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2))
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.105)
# Collecting triton==2.1.0 (from torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2))
#   Downloading triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<5.0.0,>=4.40.1->-r ./requirements/requirements-convert.txt (line 3)) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch~=2.1.1->-r ./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (1.3.0)
# Downloading numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 95.6 MB/s eta 0:00:00
# Downloading gguf-0.14.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 7.3 MB/s eta 0:00:00
# Downloading torch-2.1.2-cp311-cp311-manylinux1_x86_64.whl (670.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 1.6 MB/s eta 0:00:00
# Downloading triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nccl-cu12, nvidia-cudnn-cu12, numpy, gguf, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 3.0.0
#     Uninstalling triton-3.0.0:
#       Successfully uninstalled triton-3.0.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.20.5
#     Uninstalling nvidia-nccl-cu12-2.20.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.20.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.4.0 requires torch==2.4.0, but you have torch 2.1.2 which is incompatible.
# torchvision 0.19.0 requires torch==2.4.0, but you have torch 2.1.2 which is incompatible.
# pymc 5.20.1 requires numpy>=1.25.0, but you have numpy 1.24.4 which is incompatible.
# blosc2 3.0.0 requires numpy>=1.25.0, but you have numpy 1.24.4 which is incompatible.
# langchain 0.3.18 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# treescope 0.1.8 requires numpy>=1.25.2, but you have numpy 1.24.4 which is incompatible.
# Successfully installed gguf-0.14.0 numpy-1.24.4 nvidia-cudnn-cu12-8.9.2.26 nvidia-nccl-cu12-2.18.1 torch-2.1.2 triton-2.1.0

# %%
# !python convert-lora-to-ggml.py ../adapter-only
# Out:
# INFO:lora-to-gguf:model.layers.0.self_attn.k_proj => blk.0.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.0.self_attn.k_proj => blk.0.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.0.self_attn.o_proj => blk.0.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.0.self_attn.o_proj => blk.0.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.0.self_attn.q_proj => blk.0.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.0.self_attn.q_proj => blk.0.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.0.self_attn.v_proj => blk.0.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.0.self_attn.v_proj => blk.0.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.1.self_attn.k_proj => blk.1.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.1.self_attn.k_proj => blk.1.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.1.self_attn.o_proj => blk.1.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.1.self_attn.o_proj => blk.1.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.1.self_attn.q_proj => blk.1.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.1.self_attn.q_proj => blk.1.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.1.self_attn.v_proj => blk.1.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.1.self_attn.v_proj => blk.1.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.10.self_attn.k_proj => blk.10.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.10.self_attn.k_proj => blk.10.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.10.self_attn.o_proj => blk.10.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.10.self_attn.o_proj => blk.10.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.10.self_attn.q_proj => blk.10.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.10.self_attn.q_proj => blk.10.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.10.self_attn.v_proj => blk.10.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.10.self_attn.v_proj => blk.10.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.11.self_attn.k_proj => blk.11.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.11.self_attn.k_proj => blk.11.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.11.self_attn.o_proj => blk.11.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.11.self_attn.o_proj => blk.11.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.11.self_attn.q_proj => blk.11.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.11.self_attn.q_proj => blk.11.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.11.self_attn.v_proj => blk.11.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.11.self_attn.v_proj => blk.11.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.12.self_attn.k_proj => blk.12.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.12.self_attn.k_proj => blk.12.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.12.self_attn.o_proj => blk.12.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.12.self_attn.o_proj => blk.12.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.12.self_attn.q_proj => blk.12.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.12.self_attn.q_proj => blk.12.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.12.self_attn.v_proj => blk.12.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.12.self_attn.v_proj => blk.12.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.13.self_attn.k_proj => blk.13.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.13.self_attn.k_proj => blk.13.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.13.self_attn.o_proj => blk.13.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.13.self_attn.o_proj => blk.13.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.13.self_attn.q_proj => blk.13.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.13.self_attn.q_proj => blk.13.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.13.self_attn.v_proj => blk.13.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.13.self_attn.v_proj => blk.13.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.14.self_attn.k_proj => blk.14.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.14.self_attn.k_proj => blk.14.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.14.self_attn.o_proj => blk.14.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.14.self_attn.o_proj => blk.14.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.14.self_attn.q_proj => blk.14.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.14.self_attn.q_proj => blk.14.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.14.self_attn.v_proj => blk.14.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.14.self_attn.v_proj => blk.14.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.15.self_attn.k_proj => blk.15.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.15.self_attn.k_proj => blk.15.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.15.self_attn.o_proj => blk.15.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.15.self_attn.o_proj => blk.15.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.15.self_attn.q_proj => blk.15.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.15.self_attn.q_proj => blk.15.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.15.self_attn.v_proj => blk.15.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.15.self_attn.v_proj => blk.15.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.16.self_attn.k_proj => blk.16.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.16.self_attn.k_proj => blk.16.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.16.self_attn.o_proj => blk.16.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.16.self_attn.o_proj => blk.16.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.16.self_attn.q_proj => blk.16.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.16.self_attn.q_proj => blk.16.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.16.self_attn.v_proj => blk.16.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.16.self_attn.v_proj => blk.16.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.17.self_attn.k_proj => blk.17.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.17.self_attn.k_proj => blk.17.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.17.self_attn.o_proj => blk.17.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.17.self_attn.o_proj => blk.17.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.17.self_attn.q_proj => blk.17.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.17.self_attn.q_proj => blk.17.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.17.self_attn.v_proj => blk.17.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.17.self_attn.v_proj => blk.17.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.18.self_attn.k_proj => blk.18.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.18.self_attn.k_proj => blk.18.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.18.self_attn.o_proj => blk.18.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.18.self_attn.o_proj => blk.18.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.18.self_attn.q_proj => blk.18.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.18.self_attn.q_proj => blk.18.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.18.self_attn.v_proj => blk.18.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.18.self_attn.v_proj => blk.18.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.19.self_attn.k_proj => blk.19.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.19.self_attn.k_proj => blk.19.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.19.self_attn.o_proj => blk.19.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.19.self_attn.o_proj => blk.19.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.19.self_attn.q_proj => blk.19.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.19.self_attn.q_proj => blk.19.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.19.self_attn.v_proj => blk.19.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.19.self_attn.v_proj => blk.19.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.2.self_attn.k_proj => blk.2.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.2.self_attn.k_proj => blk.2.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.2.self_attn.o_proj => blk.2.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.2.self_attn.o_proj => blk.2.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.2.self_attn.q_proj => blk.2.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.2.self_attn.q_proj => blk.2.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.2.self_attn.v_proj => blk.2.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.2.self_attn.v_proj => blk.2.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.20.self_attn.k_proj => blk.20.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.20.self_attn.k_proj => blk.20.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.20.self_attn.o_proj => blk.20.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.20.self_attn.o_proj => blk.20.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.20.self_attn.q_proj => blk.20.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.20.self_attn.q_proj => blk.20.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.20.self_attn.v_proj => blk.20.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.20.self_attn.v_proj => blk.20.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.21.self_attn.k_proj => blk.21.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.21.self_attn.k_proj => blk.21.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.21.self_attn.o_proj => blk.21.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.21.self_attn.o_proj => blk.21.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.21.self_attn.q_proj => blk.21.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.21.self_attn.q_proj => blk.21.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.21.self_attn.v_proj => blk.21.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.21.self_attn.v_proj => blk.21.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.22.self_attn.k_proj => blk.22.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.22.self_attn.k_proj => blk.22.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.22.self_attn.o_proj => blk.22.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.22.self_attn.o_proj => blk.22.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.22.self_attn.q_proj => blk.22.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.22.self_attn.q_proj => blk.22.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.22.self_attn.v_proj => blk.22.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.22.self_attn.v_proj => blk.22.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.23.self_attn.k_proj => blk.23.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.23.self_attn.k_proj => blk.23.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.23.self_attn.o_proj => blk.23.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.23.self_attn.o_proj => blk.23.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.23.self_attn.q_proj => blk.23.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.23.self_attn.q_proj => blk.23.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.23.self_attn.v_proj => blk.23.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.23.self_attn.v_proj => blk.23.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.24.self_attn.k_proj => blk.24.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.24.self_attn.k_proj => blk.24.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.24.self_attn.o_proj => blk.24.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.24.self_attn.o_proj => blk.24.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.24.self_attn.q_proj => blk.24.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.24.self_attn.q_proj => blk.24.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.24.self_attn.v_proj => blk.24.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.24.self_attn.v_proj => blk.24.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.25.self_attn.k_proj => blk.25.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.25.self_attn.k_proj => blk.25.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.25.self_attn.o_proj => blk.25.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.25.self_attn.o_proj => blk.25.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.25.self_attn.q_proj => blk.25.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.25.self_attn.q_proj => blk.25.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.25.self_attn.v_proj => blk.25.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.25.self_attn.v_proj => blk.25.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.26.self_attn.k_proj => blk.26.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.26.self_attn.k_proj => blk.26.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.26.self_attn.o_proj => blk.26.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.26.self_attn.o_proj => blk.26.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.26.self_attn.q_proj => blk.26.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.26.self_attn.q_proj => blk.26.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.26.self_attn.v_proj => blk.26.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.26.self_attn.v_proj => blk.26.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.27.self_attn.k_proj => blk.27.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.27.self_attn.k_proj => blk.27.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.27.self_attn.o_proj => blk.27.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.27.self_attn.o_proj => blk.27.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.27.self_attn.q_proj => blk.27.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.27.self_attn.q_proj => blk.27.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.27.self_attn.v_proj => blk.27.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.27.self_attn.v_proj => blk.27.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.28.self_attn.k_proj => blk.28.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.28.self_attn.k_proj => blk.28.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.28.self_attn.o_proj => blk.28.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.28.self_attn.o_proj => blk.28.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.28.self_attn.q_proj => blk.28.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.28.self_attn.q_proj => blk.28.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.28.self_attn.v_proj => blk.28.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.28.self_attn.v_proj => blk.28.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.29.self_attn.k_proj => blk.29.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.29.self_attn.k_proj => blk.29.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.29.self_attn.o_proj => blk.29.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.29.self_attn.o_proj => blk.29.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.29.self_attn.q_proj => blk.29.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.29.self_attn.q_proj => blk.29.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.29.self_attn.v_proj => blk.29.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.29.self_attn.v_proj => blk.29.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.3.self_attn.k_proj => blk.3.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.3.self_attn.k_proj => blk.3.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.3.self_attn.o_proj => blk.3.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.3.self_attn.o_proj => blk.3.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.3.self_attn.q_proj => blk.3.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.3.self_attn.q_proj => blk.3.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.3.self_attn.v_proj => blk.3.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.3.self_attn.v_proj => blk.3.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.30.self_attn.k_proj => blk.30.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.30.self_attn.k_proj => blk.30.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.30.self_attn.o_proj => blk.30.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.30.self_attn.o_proj => blk.30.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.30.self_attn.q_proj => blk.30.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.30.self_attn.q_proj => blk.30.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.30.self_attn.v_proj => blk.30.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.30.self_attn.v_proj => blk.30.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.31.self_attn.k_proj => blk.31.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.31.self_attn.k_proj => blk.31.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.31.self_attn.o_proj => blk.31.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.31.self_attn.o_proj => blk.31.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.31.self_attn.q_proj => blk.31.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.31.self_attn.q_proj => blk.31.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.31.self_attn.v_proj => blk.31.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.31.self_attn.v_proj => blk.31.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.4.self_attn.k_proj => blk.4.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.4.self_attn.k_proj => blk.4.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.4.self_attn.o_proj => blk.4.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.4.self_attn.o_proj => blk.4.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.4.self_attn.q_proj => blk.4.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.4.self_attn.q_proj => blk.4.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.4.self_attn.v_proj => blk.4.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.4.self_attn.v_proj => blk.4.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.5.self_attn.k_proj => blk.5.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.5.self_attn.k_proj => blk.5.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.5.self_attn.o_proj => blk.5.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.5.self_attn.o_proj => blk.5.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.5.self_attn.q_proj => blk.5.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.5.self_attn.q_proj => blk.5.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.5.self_attn.v_proj => blk.5.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.5.self_attn.v_proj => blk.5.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.6.self_attn.k_proj => blk.6.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.6.self_attn.k_proj => blk.6.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.6.self_attn.o_proj => blk.6.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.6.self_attn.o_proj => blk.6.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.6.self_attn.q_proj => blk.6.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.6.self_attn.q_proj => blk.6.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.6.self_attn.v_proj => blk.6.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.6.self_attn.v_proj => blk.6.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.7.self_attn.k_proj => blk.7.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.7.self_attn.k_proj => blk.7.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.7.self_attn.o_proj => blk.7.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.7.self_attn.o_proj => blk.7.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.7.self_attn.q_proj => blk.7.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.7.self_attn.q_proj => blk.7.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.7.self_attn.v_proj => blk.7.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.7.self_attn.v_proj => blk.7.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.8.self_attn.k_proj => blk.8.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.8.self_attn.k_proj => blk.8.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.8.self_attn.o_proj => blk.8.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.8.self_attn.o_proj => blk.8.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.8.self_attn.q_proj => blk.8.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.8.self_attn.q_proj => blk.8.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.8.self_attn.v_proj => blk.8.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.8.self_attn.v_proj => blk.8.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.9.self_attn.k_proj => blk.9.attn_k.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.9.self_attn.k_proj => blk.9.attn_k.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:model.layers.9.self_attn.o_proj => blk.9.attn_output.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.9.self_attn.o_proj => blk.9.attn_output.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.9.self_attn.q_proj => blk.9.attn_q.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.9.self_attn.q_proj => blk.9.attn_q.weight.loraB (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.9.self_attn.v_proj => blk.9.attn_v.weight.loraA (4096, 4) float32 0.06MB
# INFO:lora-to-gguf:model.layers.9.self_attn.v_proj => blk.9.attn_v.weight.loraB (1024, 4) float32 0.02MB
# INFO:lora-to-gguf:Converted ../adapter-only/adapter_config.json and ../adapter-only/adapter_model.safetensors to ../adapter-only/ggml-adapter-model.bin

# %% [markdown]
# The previous line will run a script to convert your saved LoRA to a file named `ggml-adapter-model.bin` which you will find in the `adapter-only` folder in the notebook.
#
# You can right click on this file to download it to your MacBook. Then (assuming you have `llama.cpp` installed locally as well, the following is an example command that will run inference on the LoRA - note you will want to make sure the model you are doing inference on is the same as the one you trained the LoRA on (in this case `instructlab/merlinite-7b-lab` quantized down to 16 bits).
#
# ```
# !./main -m ../merlinite-7b-lab/ggml-model-f16.gguf  --seed 42 --lora ../adapter-only/ggml-adapter-model.bin --temp 0.7 --repeat_penalty 1.1 -n 256 -p "<system>\nYou are an AI language model developed by IBM Research. You are a cautious assistant. You carefully follow instructions. You are helpful and harmless and you follow ethical guidelines and promote positive behavior.\n<user>\nWho let the dogs out?\n<assistant>\n"
# ```
